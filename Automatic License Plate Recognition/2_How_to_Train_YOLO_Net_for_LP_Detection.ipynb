# %% [markdown]
# <a href="https://colab.research.google.com/github/JeanJulesBigeard/Getting-started-with-OpenCV/blob/master/Automatic%20License%20Plate%20Recognition/2_How_to_Train_YOLO_Net_for_LP_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # How to Train YOLO-Net for License Plate Detection

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this notebook, we will train YOLO-Net for License Plate (LP) detection using
# - [DarkNet framework](https://github.com/AlexeyAB/darknet.git) by Alexey - an open source neural network framework written in C and CUDA
# - [darknet53.conv](https://pjreddie.com/media/files/darknet53.conv.74) - YOLO v3 architecture based model trained on Imagenet dataset as pretrained model
# - [OpenALPR benchmark](https://platerecognizer.com/number-plate-datasets/) - as training dataset
#
# The process of training YOLO-Net for LP detection involves,
# 1. Environment Setup
# ```
#     1.1 Clone DarkNet framework
#     1.2 Compile DarkNet framework
# ```
# 2. Data Preparation
# ```
#     2.1 Download dataset
#     2.2 Generate required text files for traning
#     2.3 Download pretrained model
#     2.4 Download config file
# ```
# 3. Train the Model
#
# 4. Inference
# ```
#     4.1 Download test image
#     4.2 Utility functions
#     4.3 Load the trained model
#     4.4 Infer on the test image
#     4.5 Display inference
# ```

# %% [markdown]
# ## 1. Environment Setup

# %% [markdown]
# ### 1.1 Clone DarkNet framework

# %% [markdown]
# We will use [DarkNet framework](https://github.com/AlexeyAB/darknet.git) by Alexey which has many modifications and improvements and is actively maintained by him.

# %%
# !git clone https://github.com/AlexeyAB/darknet.git
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 25, done.
# remote: Counting objects: 100% (25/25), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 13652 (delta 8), reused 13 (delta 4), pack-reused 13627
# Receiving objects: 100% (13652/13652), 12.29 MiB | 20.20 MiB/s, done.
# Resolving deltas: 100% (9305/9305), done.

# %% [markdown]
# ### 1.2 Compile DarkNet framework

# %% [markdown]
# Before we compile, we have to make some changes to the `Makefile` to enable followings
# 1. Build darknet with OpenCV
# 1. Build with CUDA enabled
# 1. Build with cuDNN enabled

# %%
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile  # Build darknet with OpenCV
# !sed -i 's/GPU=0/GPU=1/' Makefile        # Build with CUDA enabled
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile    # Build with cuDNN enabled
# !make |& tee build_log.txt
print('Compilation of DarkNet finished...')
# Out:
# /content/darknet
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:910:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void cv_draw_object(image, float*, int, int, int*, float*, int*, int, char**)’:
# ./src/image_opencv.cpp:1391:14: warning: unused variable ‘buff’ [-Wunused-variable]
#          char buff[100];
#               ^~~~
# ./src/image_opencv.cpp:1367:9: warning: unused variable ‘it_tb_res’ [-Wunused-variable]
#      int it_tb_res = cv::createTrackbar(it_trackbar_name, window_name, &it_trackbar_value, 1000);
#          ^~~~~~~~~
# ./src/image_opencv.cpp:1371:9: warning: unused variable ‘lr_tb_res’ [-Wunused-variable]
#      int lr_tb_res = cv::createTrackbar(lr_trackbar_name, window_name, &lr_trackbar_value, 20);
#          ^~~~~~~~~
# ./src/image_opencv.cpp:1375:9: warning: unused variable ‘cl_tb_res’ [-Wunused-variable]
#      int cl_tb_res = cv::createTrackbar(cl_trackbar_name, window_name, &cl_trackbar_value, classes-1);
#          ^~~~~~~~~
# ./src/image_opencv.cpp:1378:9: warning: unused variable ‘bo_tb_res’ [-Wunused-variable]
#      int bo_tb_res = cv::createTrackbar(bo_trackbar_name, window_name, boxonly, 1);
#          ^~~~~~~~~
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/http_stream.cpp -o obj/http_stream.o
# In file included from ./src/http_stream.cpp:580:0:
# ./src/httplib.h:129:0: warning: "INVALID_SOCKET" redefined
#  #define INVALID_SOCKET (-1)
#
# ./src/http_stream.cpp:73:0: note: this is the location of the previous definition
#  #define INVALID_SOCKET -1
#
# ./src/http_stream.cpp: In member function ‘bool JSON_sender::write(const char*)’:
# ./src/http_stream.cpp:249:21: warning: unused variable ‘n’ [-Wunused-variable]
#                  int n = _write(client, outputbuf, outlen);
#                      ^
# ./src/http_stream.cpp: In member function ‘bool MJPG_sender::write(const cv::Mat&)’:
# ./src/http_stream.cpp:507:113: warning: format ‘%zu’ expects argument of type ‘size_t’, but argument 3 has type ‘int’ [-Wformat=]
#                  sprintf(head, "--mjpegstream\r\nContent-Type: image/jpeg\r\nContent-Length: %zu\r\n\r\n", outlen);
#                                                                                                                  ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/gemm.c -o obj/gemm.o
# ./src/gemm.c: In function ‘convolution_2d’:
# ./src/gemm.c:2038:15: warning: unused variable ‘out_w’ [-Wunused-variable]
#      const int out_w = (w + 2 * pad - ksize) / stride + 1;    // output_width=input_width for stride=1 and pad=1
#                ^~~~~
# ./src/gemm.c:2037:15: warning: unused variable ‘out_h’ [-Wunused-variable]
#      const int out_h = (h + 2 * pad - ksize) / stride + 1;    // output_height=input_height for stride=1 and pad=1
#                ^~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/utils.c -o obj/utils.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/dark_cuda.c -o obj/dark_cuda.o
# ./src/dark_cuda.c: In function ‘cudnn_check_error_extended’:
# ./src/dark_cuda.c:224:20: warning: comparison between ‘cudaError_t {aka enum cudaError}’ and ‘enum <anonymous>’ [-Wenum-compare]
#          if (status != CUDNN_STATUS_SUCCESS)
#                     ^~
# ./src/dark_cuda.c: In function ‘pre_allocate_pinned_memory’:
# ./src/dark_cuda.c:276:40: warning: format ‘%u’ expects argument of type ‘unsigned int’, but argument 2 has type ‘long unsigned int’ [-Wformat=]
#          printf("pre_allocate: size = %Iu MB, num_of_blocks = %Iu, block_size = %Iu MB \n",
#                                       ~~^
#                                       %Ilu
#              size / (1024*1024), num_of_blocks, pinned_block_size / (1024 * 1024));
#              ~~~~~~~~~~~~~~~~~~
# ./src/dark_cuda.c:276:64: warning: format ‘%u’ expects argument of type ‘unsigned int’, but argument 3 has type ‘size_t {aka const long unsigned int}’ [-Wformat=]
#          printf("pre_allocate: size = %Iu MB, num_of_blocks = %Iu, block_size = %Iu MB \n",
#                                                               ~~^
#                                                               %Ilu
# ./src/dark_cuda.c:276:82: warning: format ‘%u’ expects argument of type ‘unsigned int’, but argument 4 has type ‘long unsigned int’ [-Wformat=]
#          printf("pre_allocate: size = %Iu MB, num_of_blocks = %Iu, block_size = %Iu MB \n",
#                                                                                 ~~^
#                                                                                 %Ilu
# ./src/dark_cuda.c:286:37: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘size_t {aka const long unsigned int}’ [-Wformat=]
#                  printf(" Allocated %d pinned block \n", pinned_block_size);
#                                     ~^
#                                     %ld
# ./src/dark_cuda.c: In function ‘cuda_make_array_pinned_preallocated’:
# ./src/dark_cuda.c:307:43: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#              printf("\n Pinned block_id = %d, filled = %f %% \n", pinned_block_id, filled);
#                                           ~^
#                                           %ld
# ./src/dark_cuda.c:322:64: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘long unsigned int’ [-Wformat=]
#              printf("Try to allocate new pinned memory, size = %d MB \n", size / (1024 * 1024));
#                                                                ~^         ~~~~~~~~~~~~~~~~~~~~
#                                                                %ld
# ./src/dark_cuda.c:328:63: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘long unsigned int’ [-Wformat=]
#              printf("Try to allocate new pinned BLOCK, size = %d MB \n", size / (1024 * 1024));
#                                                               ~^         ~~~~~~~~~~~~~~~~~~~~
#                                                               %ld
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/convolutional_layer.c -o obj/convolutional_layer.o
# ./src/convolutional_layer.c: In function ‘forward_convolutional_layer’:
# ./src/convolutional_layer.c:1204:32: warning: unused variable ‘t_intput_size’ [-Wunused-variable]
#                          size_t t_intput_size = binary_transpose_align_input(k, n, state.workspace, &l.t_bit_input, ldb_align, l.bit_align);
#                                 ^~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/list.c -o obj/list.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image.c -o obj/image.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/activations.c -o obj/activations.o
# ./src/activations.c: In function ‘activate’:
# ./src/activations.c:77:5: warning: enumeration value ‘RELU6’ not handled in switch [-Wswitch]
#      switch(a){
#      ^~~~~~
# ./src/activations.c:77:5: warning: enumeration value ‘SWISH’ not handled in switch [-Wswitch]
# ./src/activations.c:77:5: warning: enumeration value ‘MISH’ not handled in switch [-Wswitch]
# ./src/activations.c:77:5: warning: enumeration value ‘NORM_CHAN’ not handled in switch [-Wswitch]
# ./src/activations.c:77:5: warning: enumeration value ‘NORM_CHAN_SOFTMAX’ not handled in switch [-Wswitch]
# ./src/activations.c:77:5: warning: enumeration value ‘NORM_CHAN_SOFTMAX_MAXVAL’ not handled in switch [-Wswitch]
# ./src/activations.c: In function ‘gradient’:
# ./src/activations.c:287:5: warning: enumeration value ‘SWISH’ not handled in switch [-Wswitch]
#      switch(a){
#      ^~~~~~
# ./src/activations.c:287:5: warning: enumeration value ‘MISH’ not handled in switch [-Wswitch]
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/im2col.c -o obj/im2col.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/col2im.c -o obj/col2im.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/blas.c -o obj/blas.o
# ./src/blas.c: In function ‘backward_shortcut_multilayer_cpu’:
# ./src/blas.c:207:21: warning: unused variable ‘out_index’ [-Wunused-variable]
#                  int out_index = id;
#                      ^~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/crop_layer.c -o obj/crop_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/dropout_layer.c -o obj/dropout_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/maxpool_layer.c -o obj/maxpool_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/softmax_layer.c -o obj/softmax_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/data.c -o obj/data.o
# ./src/data.c: In function ‘load_data_detection’:
# ./src/data.c:1242:24: warning: unused variable ‘x’ [-Wunused-variable]
#                  int k, x, y;
#                         ^
# ./src/data.c:1043:43: warning: variable ‘r_scale’ set but not used [-Wunused-but-set-variable]
#      float r1 = 0, r2 = 0, r3 = 0, r4 = 0, r_scale = 0;
#                                            ^~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/matrix.c -o obj/matrix.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/network.c -o obj/network.o
# ./src/network.c: In function ‘resize_network’:
# ./src/network.c:614:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess == cudaHostAlloc(&net->input_pinned_cpu, size * sizeof(float), cudaHostRegisterMapped))
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/network.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4391:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/connected_layer.c -o obj/connected_layer.o
# ./src/connected_layer.c: In function ‘forward_connected_layer_gpu’:
# ./src/connected_layer.c:346:11: warning: unused variable ‘one’ [-Wunused-variable]
#      float one = 1;    // alpha[0], beta[0]
#            ^~~
# ./src/connected_layer.c:344:13: warning: unused variable ‘c’ [-Wunused-variable]
#      float * c = l.output_gpu;
#              ^
# ./src/connected_layer.c:343:13: warning: unused variable ‘b’ [-Wunused-variable]
#      float * b = l.weights_gpu;
#              ^
# ./src/connected_layer.c:342:13: warning: unused variable ‘a’ [-Wunused-variable]
#      float * a = state.input;
#              ^
# ./src/connected_layer.c:341:9: warning: unused variable ‘n’ [-Wunused-variable]
#      int n = l.outputs;
#          ^
# ./src/connected_layer.c:340:9: warning: unused variable ‘k’ [-Wunused-variable]
#      int k = l.inputs;
#          ^
# ./src/connected_layer.c:339:9: warning: unused variable ‘m’ [-Wunused-variable]
#      int m = l.batch;
#          ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/cost_layer.c -o obj/cost_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/parser.c -o obj/parser.o
# ./src/parser.c: In function ‘parse_network_cfg_custom’:
# ./src/parser.c:1592:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess == cudaHostAlloc(&net.input_pinned_cpu, size * sizeof(float), cudaHostRegisterMapped)) net.input_pinned_cpu_flag = 1;
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/activation_layer.h:4,
#                  from ./src/parser.c:6:
# /usr/local/cuda/include/cuda_runtime_api.h:4391:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/option_list.c -o obj/option_list.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/darknet.c -o obj/darknet.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/detection_layer.c -o obj/detection_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/captcha.c -o obj/captcha.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/route_layer.c -o obj/route_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/writing.c -o obj/writing.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/box.c -o obj/box.o
# ./src/box.c: In function ‘box_iou_kind’:
# ./src/box.c:154:5: warning: enumeration value ‘MSE’ not handled in switch [-Wswitch]
#      switch(iou_kind) {
#      ^~~~~~
# ./src/box.c: In function ‘diounms_sort’:
# ./src/box.c:898:27: warning: unused variable ‘beta_prob’ [-Wunused-variable]
#                      float beta_prob = pow(dets[j].prob[k], 2) / sum_prob;
#                            ^~~~~~~~~
# ./src/box.c:897:27: warning: unused variable ‘alpha_prob’ [-Wunused-variable]
#                      float alpha_prob = pow(dets[i].prob[k], 2) / sum_prob;
#                            ^~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/nightmare.c -o obj/nightmare.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/normalization_layer.c -o obj/normalization_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/avgpool_layer.c -o obj/avgpool_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/coco.c -o obj/coco.o
# ./src/coco.c: In function ‘validate_coco_recall’:
# ./src/coco.c:248:11: warning: unused variable ‘base’ [-Wunused-variable]
#      char *base = "results/comp4_det_test_";
#            ^~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/dice.c -o obj/dice.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/yolo.c -o obj/yolo.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/detector.c -o obj/detector.o
# ./src/detector.c: In function ‘print_cocos’:
# ./src/detector.c:456:29: warning: format not a string literal and no format arguments [-Wformat-security]
#                  fprintf(fp, buff);
#                              ^~~~
# ./src/detector.c: In function ‘eliminate_bdd’:
# ./src/detector.c:549:21: warning: statement with no effect [-Wunused-value]
#                      for (k; buf[k + n] != '\0'; k++)
#                      ^~~
# ./src/detector.c: In function ‘validate_detector’:
# ./src/detector.c:662:13: warning: unused variable ‘mkd2’ [-Wunused-variable]
#          int mkd2 = make_directory(buff2, 0777);
#              ^~~~
# ./src/detector.c:660:13: warning: unused variable ‘mkd’ [-Wunused-variable]
#          int mkd = make_directory(buff, 0777);
#              ^~~
# ./src/detector.c: In function ‘validate_detector_map’:
# ./src/detector.c:1281:15: warning: unused variable ‘class_recall’ [-Wunused-variable]
#          float class_recall = (float)tp_for_thresh_per_class[i] / ((float)tp_for_thresh_per_class[i] + (float)(truth_classes_count[i] - tp_for_thresh_per_class[i]));
#                ^~~~~~~~~~~~
# ./src/detector.c:1280:15: warning: unused variable ‘class_precision’ [-Wunused-variable]
#          float class_precision = (float)tp_for_thresh_per_class[i] / ((float)tp_for_thresh_per_class[i] + (float)fp_for_thresh_per_class[i]);
#                ^~~~~~~~~~~~~~~
# ./src/detector.c: In function ‘draw_object’:
# ./src/detector.c:1797:19: warning: unused variable ‘inv_loss’ [-Wunused-variable]
#              float inv_loss = 1.0 / max_val_cmp(0.01, avg_loss);
#                    ^~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/layer.c -o obj/layer.o
# ./src/layer.c: In function ‘free_layer_custom’:
# ./src/layer.c:198:68: warning: suggest parentheses around ‘&&’ within ‘||’ [-Wparentheses]
#      if (l.delta_gpu && (l.optimized_memory < 1 || l.keep_delta_gpu && l.optimized_memory < 3)) cuda_free(l.delta_gpu), l.delta_gpu = NULL;
#                                                    ~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/compare.c -o obj/compare.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/classifier.c -o obj/classifier.o
# ./src/classifier.c: In function ‘train_classifier’:
# ./src/classifier.c:138:9: warning: unused variable ‘count’ [-Wunused-variable]
#      int count = 0;
#          ^~~~~
# ./src/classifier.c: In function ‘predict_classifier’:
# ./src/classifier.c:831:13: warning: unused variable ‘time’ [-Wunused-variable]
#      clock_t time;
#              ^~~~
# ./src/classifier.c: In function ‘demo_classifier’:
# ./src/classifier.c:1261:49: warning: unused variable ‘tval_result’ [-Wunused-variable]
#          struct timeval tval_before, tval_after, tval_result;
#                                                  ^~~~~~~~~~~
# ./src/classifier.c:1261:37: warning: unused variable ‘tval_after’ [-Wunused-variable]
#          struct timeval tval_before, tval_after, tval_result;
#                                      ^~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/local_layer.c -o obj/local_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/swag.c -o obj/swag.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/shortcut_layer.c -o obj/shortcut_layer.o
# ./src/shortcut_layer.c: In function ‘make_shortcut_layer’:
# ./src/shortcut_layer.c:55:15: warning: unused variable ‘scale’ [-Wunused-variable]
#          float scale = sqrt(2. / l.nweights);
#                ^~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/activation_layer.c -o obj/activation_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/rnn_layer.c -o obj/rnn_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/gru_layer.c -o obj/gru_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/rnn.c -o obj/rnn.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/rnn_vid.c -o obj/rnn_vid.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/crnn_layer.c -o obj/crnn_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/demo.c -o obj/demo.o
# ./src/demo.c: In function ‘detect_in_thread’:
# ./src/demo.c:100:16: warning: unused variable ‘prediction’ [-Wunused-variable]
#          float *prediction = network_predict(net, X);
#                 ^~~~~~~~~~
# ./src/demo.c:98:15: warning: unused variable ‘l’ [-Wunused-variable]
#          layer l = net.layers[net.n - 1];
#                ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/tag.c -o obj/tag.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/cifar.c -o obj/cifar.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/go.c -o obj/go.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/batchnorm_layer.c -o obj/batchnorm_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/art.c -o obj/art.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/region_layer.c -o obj/region_layer.o
# ./src/region_layer.c: In function ‘resize_region_layer’:
# ./src/region_layer.c:58:9: warning: unused variable ‘old_h’ [-Wunused-variable]
#      int old_h = l->h;
#          ^~~~~
# ./src/region_layer.c:57:9: warning: unused variable ‘old_w’ [-Wunused-variable]
#      int old_w = l->w;
#          ^~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/reorg_layer.c -o obj/reorg_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/reorg_old_layer.c -o obj/reorg_old_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/super.c -o obj/super.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/voxel.c -o obj/voxel.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/tree.c -o obj/tree.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/yolo_layer.c -o obj/yolo_layer.o
# ./src/yolo_layer.c: In function ‘make_yolo_layer’:
# ./src/yolo_layer.c:62:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#      if (cudaSuccess == cudaHostAlloc(&l.output, batch*l.outputs*sizeof(float), cudaHostRegisterMapped)) l.output_pinned = 1;
#                                       ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4391:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/yolo_layer.c:69:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#      if (cudaSuccess == cudaHostAlloc(&l.delta, batch*l.outputs*sizeof(float), cudaHostRegisterMapped)) l.delta_pinned = 1;
#                                       ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4391:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/yolo_layer.c: In function ‘resize_yolo_layer’:
# ./src/yolo_layer.c:96:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess != cudaHostAlloc(&l->output, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4391:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/yolo_layer.c:105:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess != cudaHostAlloc(&l->delta, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4391:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/gaussian_yolo_layer.c -o obj/gaussian_yolo_layer.o
# ./src/gaussian_yolo_layer.c: In function ‘make_gaussian_yolo_layer’:
# ./src/gaussian_yolo_layer.c:71:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#      if (cudaSuccess == cudaHostAlloc(&l.output, batch*l.outputs * sizeof(float), cudaHostRegisterMapped)) l.output_pinned = 1;
#                                       ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/gaussian_yolo_layer.h:5,
#                  from ./src/gaussian_yolo_layer.c:7:
# /usr/local/cuda/include/cuda_runtime_api.h:4391:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/gaussian_yolo_layer.c:78:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#      if (cudaSuccess == cudaHostAlloc(&l.delta, batch*l.outputs * sizeof(float), cudaHostRegisterMapped)) l.delta_pinned = 1;
#                                       ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/gaussian_yolo_layer.h:5,
#                  from ./src/gaussian_yolo_layer.c:7:
# /usr/local/cuda/include/cuda_runtime_api.h:4391:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/gaussian_yolo_layer.c: In function ‘resize_gaussian_yolo_layer’:
# ./src/gaussian_yolo_layer.c:110:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess != cudaHostAlloc(&l->output, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/gaussian_yolo_layer.h:5,
#                  from ./src/gaussian_yolo_layer.c:7:
# /usr/local/cuda/include/cuda_runtime_api.h:4391:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/gaussian_yolo_layer.c:119:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess != cudaHostAlloc(&l->delta, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/gaussian_yolo_layer.h:5,
#                  from ./src/gaussian_yolo_layer.c:7:
# /usr/local/cuda/include/cuda_runtime_api.h:4391:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/upsample_layer.c -o obj/upsample_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/lstm_layer.c -o obj/lstm_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/conv_lstm_layer.c -o obj/conv_lstm_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/scale_channels_layer.c -o obj/scale_channels_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/sam_layer.c -o obj/sam_layer.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/convolutional_kernels.cu -o obj/convolutional_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/activation_kernels.cu -o obj/activation_kernels.o
# ./src/activation_kernels.cu(253): warning: variable "MISH_THRESHOLD" was declared but never referenced
#
# ./src/activation_kernels.cu(253): warning: variable "MISH_THRESHOLD" was declared but never referenced
#
# ./src/activation_kernels.cu(253): warning: variable "MISH_THRESHOLD" was declared but never referenced
#
# ./src/activation_kernels.cu(253): warning: variable "MISH_THRESHOLD" was declared but never referenced
#
# ./src/activation_kernels.cu(253): warning: variable "MISH_THRESHOLD" was declared but never referenced
#
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/im2col_kernels.cu -o obj/im2col_kernels.o
# ./src/im2col_kernels.cu:125:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#
# ./src/im2col_kernels.cu:1178:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#
# ./src/im2col_kernels.cu:125:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#
# ./src/im2col_kernels.cu:1178:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#
# ./src/im2col_kernels.cu:125:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#
# ./src/im2col_kernels.cu:1178:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#
# ./src/im2col_kernels.cu:125:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#
# ./src/im2col_kernels.cu:1178:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#
# ./src/im2col_kernels.cu:125:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#
# ./src/im2col_kernels.cu:1178:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#
# ./src/im2col_kernels.cu:125:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#
# ./src/im2col_kernels.cu:1178:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/col2im_kernels.cu -o obj/col2im_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/blas_kernels.cu -o obj/blas_kernels.o
# ./src/blas_kernels.cu(1086): warning: variable "out_index" was declared but never referenced
#
# ./src/blas_kernels.cu(1130): warning: variable "step" was set but never used
#
# ./src/blas_kernels.cu(1736): warning: variable "stage_id" was declared but never referenced
#
# ./src/blas_kernels.cu(1086): warning: variable "out_index" was declared but never referenced
#
# ./src/blas_kernels.cu(1130): warning: variable "step" was set but never used
#
# ./src/blas_kernels.cu(1736): warning: variable "stage_id" was declared but never referenced
#
# ./src/blas_kernels.cu(1086): warning: variable "out_index" was declared but never referenced
#
# ./src/blas_kernels.cu(1130): warning: variable "step" was set but never used
#
# ./src/blas_kernels.cu(1736): warning: variable "stage_id" was declared but never referenced
#
# ./src/blas_kernels.cu(1086): warning: variable "out_index" was declared but never referenced
#
# ./src/blas_kernels.cu(1130): warning: variable "step" was set but never used
#
# ./src/blas_kernels.cu(1736): warning: variable "stage_id" was declared but never referenced
#
# ./src/blas_kernels.cu(1086): warning: variable "out_index" was declared but never referenced
#
# ./src/blas_kernels.cu(1130): warning: variable "step" was set but never used
#
# ./src/blas_kernels.cu(1736): warning: variable "stage_id" was declared but never referenced
#
# ./src/blas_kernels.cu: In function ‘void backward_shortcut_multilayer_gpu(int, int, int, int*, float**, float*, float*, float*, float*, int, float*, float**, WEIGHTS_NORMALIZATION_T)’:
# ./src/blas_kernels.cu:1130:5: warning: variable ‘step’ set but not used [-Wunused-but-set-variable]
#      int step = 0;
#      ^~~~
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/crop_layer_kernels.cu -o obj/crop_layer_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/dropout_layer_kernels.cu -o obj/dropout_layer_kernels.o
# ./src/dropout_layer_kernels.cu(140): warning: variable "cur_scale" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(245): warning: variable "cur_scale" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(262): warning: variable "block_prob" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(140): warning: variable "cur_scale" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(245): warning: variable "cur_scale" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(262): warning: variable "block_prob" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(140): warning: variable "cur_scale" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(245): warning: variable "cur_scale" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(262): warning: variable "block_prob" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(140): warning: variable "cur_scale" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(245): warning: variable "cur_scale" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(262): warning: variable "block_prob" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(140): warning: variable "cur_scale" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(245): warning: variable "cur_scale" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(262): warning: variable "block_prob" was declared but never referenced
#
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/maxpool_layer_kernels.cu -o obj/maxpool_layer_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/network_kernels.cu -o obj/network_kernels.o
# ./src/network_kernels.cu(363): warning: variable "l" was declared but never referenced
#
# ./src/network_kernels.cu(372): warning: variable "im" was set but never used
#
# ./src/network_kernels.cu(363): warning: variable "l" was declared but never referenced
#
# ./src/network_kernels.cu(372): warning: variable "im" was set but never used
#
# ./src/network_kernels.cu(363): warning: variable "l" was declared but never referenced
#
# ./src/network_kernels.cu(372): warning: variable "im" was set but never used
#
# ./src/network_kernels.cu(363): warning: variable "l" was declared but never referenced
#
# ./src/network_kernels.cu(372): warning: variable "im" was set but never used
#
# ./src/network_kernels.cu(363): warning: variable "l" was declared but never referenced
#
# ./src/network_kernels.cu(372): warning: variable "im" was set but never used
#
# ./src/network_kernels.cu: In function ‘float train_network_datum_gpu(network, float*, float*)’:
# ./src/network_kernels.cu:363:7: warning: variable ‘l’ set but not used [-Wunused-but-set-variable]
#          layer l = net.layers[net.n - 1];
#        ^
# ./src/network_kernels.cu:372:7: warning: variable ‘im’ set but not used [-Wunused-but-set-variable]
#          image im;
#        ^
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/avgpool_layer_kernels.cu -o obj/avgpool_layer_kernels.o
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include obj/image_opencv.o obj/http_stream.o obj/gemm.o obj/utils.o obj/dark_cuda.o obj/convolutional_layer.o obj/list.o obj/image.o obj/activations.o obj/im2col.o obj/col2im.o obj/blas.o obj/crop_layer.o obj/dropout_layer.o obj/maxpool_layer.o obj/softmax_layer.o obj/data.o obj/matrix.o obj/network.o obj/connected_layer.o obj/cost_layer.o obj/parser.o obj/option_list.o obj/darknet.o obj/detection_layer.o obj/captcha.o obj/route_layer.o obj/writing.o obj/box.o obj/nightmare.o obj/normalization_layer.o obj/avgpool_layer.o obj/coco.o obj/dice.o obj/yolo.o obj/detector.o obj/layer.o obj/compare.o obj/classifier.o obj/local_layer.o obj/swag.o obj/shortcut_layer.o obj/activation_layer.o obj/rnn_layer.o obj/gru_layer.o obj/rnn.o obj/rnn_vid.o obj/crnn_layer.o obj/demo.o obj/tag.o obj/cifar.o obj/go.o obj/batchnorm_layer.o obj/art.o obj/region_layer.o obj/reorg_layer.o obj/reorg_old_layer.o obj/super.o obj/voxel.o obj/tree.o obj/yolo_layer.o obj/gaussian_yolo_layer.o obj/upsample_layer.o obj/lstm_layer.o obj/conv_lstm_layer.o obj/scale_channels_layer.o obj/sam_layer.o obj/convolutional_kernels.o obj/activation_kernels.o obj/im2col_kernels.o obj/col2im_kernels.o obj/blas_kernels.o obj/crop_layer_kernels.o obj/dropout_layer_kernels.o obj/maxpool_layer_kernels.o obj/network_kernels.o obj/avgpool_layer_kernels.o -o darknet -lm -pthread `pkg-config --libs opencv4 2> /dev/null || pkg-config --libs opencv` -L/usr/local/cuda/lib64 -lcuda -lcudart -lcublas -lcurand -L/usr/local/cudnn/lib64 -lcudnn -lstdc++
# Compilation of DarkNet finished...

# %% [markdown]
# ## 2. Data Preparation

# %% [markdown]
# ### 2.1 Download dataset

# %% [markdown]
# [OpenALPR benchmark](https://github.com/openalpr/benchmarks/tree/master/endtoend/) is a collection of labeled images of vehicles in Europe, Brazil and the US. Each has bounding box around the plate and the value of the license plate.
#
# To train on custom dataset, we need to create `.txt`-file for each `.jpg`-image-file - in the same directory and with the same name, but with `.txt`-extension, and put to file: object number and object coordinates on this image, for each object in new line:
#
# `<object-class> <x_center> <y_center> <width> <height>`
#
#   Where:
#   * `<object-class>` - integer object number from `0` to `(classes-1)`
#   * `<x_center> <y_center> <width> <height>` - float values **relative** to width and height of image, it can be equal from `(0.0 to 1.0]`
#   * for example: `<x> = <absolute_x> / <image_width>` or `<height> = <absolute_height> / <image_height>`
#   * Note: `<x_center> <y_center>` - are center of rectangle (are not top-left corner)
#
# We have shared prepared dataset which can be download from [here](https://www.dropbox.com/s/x38sqxxmem335gv/images.zip?dl=0).

# %%
# !wget "https://www.dropbox.com/s/x38sqxxmem335gv/images.zip?dl=0" -O dataset.zip
# !unzip -q dataset.zip
# Out:
# --2020-06-08 15:44:31--  https://www.dropbox.com/s/x38sqxxmem335gv/images.zip?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.5.1, 2620:100:601d:1::a27d:501
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.5.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/x38sqxxmem335gv/images.zip [following]
# --2020-06-08 15:44:31--  https://www.dropbox.com/s/raw/x38sqxxmem335gv/images.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uca20105412cfe6727167695777c.dl.dropboxusercontent.com/cd/0/inline/A5RD12A2qoXlGl-HU4KEJwmynO_n4Qnj0U1BIK6ilNHcaTbek_PZgtyysaWqnvXBoRweqsaWpQb4s8q4ObC3umx4__gacYKZAgxO0CNPKgbOO4nhdNyLmsT59mD_Bxf7yjc/file# [following]
# --2020-06-08 15:44:31--  https://uca20105412cfe6727167695777c.dl.dropboxusercontent.com/cd/0/inline/A5RD12A2qoXlGl-HU4KEJwmynO_n4Qnj0U1BIK6ilNHcaTbek_PZgtyysaWqnvXBoRweqsaWpQb4s8q4ObC3umx4__gacYKZAgxO0CNPKgbOO4nhdNyLmsT59mD_Bxf7yjc/file
# Resolving uca20105412cfe6727167695777c.dl.dropboxusercontent.com (uca20105412cfe6727167695777c.dl.dropboxusercontent.com)... 162.125.5.15, 2620:100:601d:15::a27d:50f
# Connecting to uca20105412cfe6727167695777c.dl.dropboxusercontent.com (uca20105412cfe6727167695777c.dl.dropboxusercontent.com)|162.125.5.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/A5RWa3t145P5d2NlNn-L0ObcBOw5QZEwpqszaQkvZp2syC1jSVirVrRwe903QOs4kwb96wETTcnvNGCzQeLTi_VXVjmnyW0eZNh4Xu6udJtjZz91H4sDQpLRjnwLTXJPWEOqmxD52Me9GvCsGSJCIeHBcmg4Xx5oqNxjGEZUoI12wkNs5w919G6rtW32yuAzg81ewan5XZtjUKfZ9usprvQg7hFj01xn_wWsiYQJb1at4F4HPquICZM3paGrOc8FDhr6Got6dhsnsFhMlF6LqSM4CZMvIC6tvlmdyAsASqpzn1uCNuclM2usJoGUQMRZXkY73N052RZ3-p43WBpPvAFXlsNx6s5-RpUJJ0pXTtk79A/file [following]
# --2020-06-08 15:44:32--  https://uca20105412cfe6727167695777c.dl.dropboxusercontent.com/cd/0/inline2/A5RWa3t145P5d2NlNn-L0ObcBOw5QZEwpqszaQkvZp2syC1jSVirVrRwe903QOs4kwb96wETTcnvNGCzQeLTi_VXVjmnyW0eZNh4Xu6udJtjZz91H4sDQpLRjnwLTXJPWEOqmxD52Me9GvCsGSJCIeHBcmg4Xx5oqNxjGEZUoI12wkNs5w919G6rtW32yuAzg81ewan5XZtjUKfZ9usprvQg7hFj01xn_wWsiYQJb1at4F4HPquICZM3paGrOc8FDhr6Got6dhsnsFhMlF6LqSM4CZMvIC6tvlmdyAsASqpzn1uCNuclM2usJoGUQMRZXkY73N052RZ3-p43WBpPvAFXlsNx6s5-RpUJJ0pXTtk79A/file
# Reusing existing connection to uca20105412cfe6727167695777c.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 113328015 (108M) [application/zip]
# Saving to: ‘dataset.zip’
#
# dataset.zip         100%[===================>] 108.08M  51.1MB/s    in 2.1s
#
# 2020-06-08 15:44:35 (51.1 MB/s) - ‘dataset.zip’ saved [113328015/113328015]

# %% [markdown]
# ### 2.2 Generate required text files for traning

# %% [markdown]
# We will create two text file 1) `data_train.txt` and 2) `data_test.txt` which contains absolute path to train images and test images respectively. The dataset is split into train and test in the ratio of 90:10. So, we will use 90% of the total images for training and the rest for testing after a few iterations of training.

# %%
import random
import os
import subprocess
import sys

image_dir = "./images"
f_val = open("data_test.txt", 'w')
f_train = open("data_train.txt", 'w')

path, dirs, files = next(os.walk(image_dir))
data_size = len(files)

ind = 0
data_test_size = int(0.2 * data_size)
test_array = random.sample(range(data_size), k=data_test_size)

for f in os.listdir(image_dir):
  if(f.split(".")[-1] == "jpg"):
    ind += 1
      
    if ind in test_array:
      f_val.write(image_dir+'/'+f+'\n')
    else:
      f_train.write(image_dir+'/'+f+'\n')

f_train.close()
f_val.close()

# %% [markdown]
# ### 2.3 Download pretrained model

# %% [markdown]
# When you train an object detector on custom dataset, it is a good idea to leverage existing models trained on very large datasets even though the large dataset may not contain the object you are trying to detect. This process is called *transfer learning*.
#
# We will use YOLO v3 architecture based model trained on Imagenet dataset as pretrained model.

# %%
# !wget "https://www.dropbox.com/s/18dwbfth7prbf0h/darknet53.conv.74?dl=1" -O darknet53.conv.74
# Out:
# --2020-06-08 15:52:48--  https://www.dropbox.com/s/18dwbfth7prbf0h/darknet53.conv.74?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.5.1, 2620:100:601d:1::a27d:501
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.5.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/dl/18dwbfth7prbf0h/darknet53.conv.74 [following]
# --2020-06-08 15:52:49--  https://www.dropbox.com/s/dl/18dwbfth7prbf0h/darknet53.conv.74
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc623ba2596ab3be5871cb926eff.dl.dropboxusercontent.com/cd/0/get/A5RJ_elwGLLehGg02rcOLR1j9LAyS_Jy33xASdlu4gHDmvIJQFeQQZnM5drRrCuZw2e3y38Js1BA8YcWACO8Z4gdDgFkRiBMAwwBR7Fecf1dCGOEeHrPpNGnK2A2xj0j4xw/file?dl=1# [following]
# --2020-06-08 15:52:49--  https://uc623ba2596ab3be5871cb926eff.dl.dropboxusercontent.com/cd/0/get/A5RJ_elwGLLehGg02rcOLR1j9LAyS_Jy33xASdlu4gHDmvIJQFeQQZnM5drRrCuZw2e3y38Js1BA8YcWACO8Z4gdDgFkRiBMAwwBR7Fecf1dCGOEeHrPpNGnK2A2xj0j4xw/file?dl=1
# Resolving uc623ba2596ab3be5871cb926eff.dl.dropboxusercontent.com (uc623ba2596ab3be5871cb926eff.dl.dropboxusercontent.com)... 162.125.5.15, 2620:100:601d:15::a27d:50f
# Connecting to uc623ba2596ab3be5871cb926eff.dl.dropboxusercontent.com (uc623ba2596ab3be5871cb926eff.dl.dropboxusercontent.com)|162.125.5.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/binary]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M  37.1MB/s    in 4.2s
#
# 2020-06-08 15:52:54 (37.1 MB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %% [markdown]
# ### 2.4 Download Config file

# %% [markdown]
# We have provided config files to specify the various training parameters. A gist of all the parameters is as follows,
#
# 1. `class.names`: contains the names of all the classes to be trained. In our case it contains `License plate` as class name.
# 1. `yolov3-LP-train.cfg`: contains model training related parameters
# 1. `yolov3-LP-test.cfg`: contains parameters related to model testing
# 1. `yolov3-LP-setup.data`: The content of the file is as follow
# >
# ```shell
# classes = 1 # number of object classes. It's 1 in our case.
# train   = data_train.txt # path to text file containing absolute path to train images
# valid   = data_test.txt # path to text file containing absolute path to test images
# names   = class.names # path to file contain the names of all classses
# backup  = backup/ # path to an existing directory where intermediate weights files will be stored as the training progresses
# ```

# %%
# !wget "https://www.dropbox.com/sh/5y72h8ul8654y9i/AAAFwOwOl7bsQ4BmuxraKBRta?dl=0" -O yolov3_LP.zip
# !unzip -q yolov3_LP.zip
# Out:
# --2020-06-08 15:52:55--  https://www.dropbox.com/sh/5y72h8ul8654y9i/AAAFwOwOl7bsQ4BmuxraKBRta?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.5.1, 2620:100:601d:1::a27d:501
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.5.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /sh/raw/5y72h8ul8654y9i/AAAFwOwOl7bsQ4BmuxraKBRta [following]
# --2020-06-08 15:52:56--  https://www.dropbox.com/sh/raw/5y72h8ul8654y9i/AAAFwOwOl7bsQ4BmuxraKBRta
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc4973990784ae0b4d0c5b2b1567.dl.dropboxusercontent.com/zip_download_get/AcqYCwXcUy1MXWVuRqR5aZ29iAJ-HCN2LvsNs04RNO7h7UCj6XfPCtSI_E0TeCBIW1yzRMjpgSxAaevrjbQGu2vnf2Rfuypk96rrOHXtkqHYNQ [following]
# --2020-06-08 15:52:56--  https://uc4973990784ae0b4d0c5b2b1567.dl.dropboxusercontent.com/zip_download_get/AcqYCwXcUy1MXWVuRqR5aZ29iAJ-HCN2LvsNs04RNO7h7UCj6XfPCtSI_E0TeCBIW1yzRMjpgSxAaevrjbQGu2vnf2Rfuypk96rrOHXtkqHYNQ
# Resolving uc4973990784ae0b4d0c5b2b1567.dl.dropboxusercontent.com (uc4973990784ae0b4d0c5b2b1567.dl.dropboxusercontent.com)... 162.125.5.15, 2620:100:601d:15::a27d:50f
# Connecting to uc4973990784ae0b4d0c5b2b1567.dl.dropboxusercontent.com (uc4973990784ae0b4d0c5b2b1567.dl.dropboxusercontent.com)|162.125.5.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 17600 (17K) [application/zip]
# Saving to: ‘yolov3_LP.zip’
#
# yolov3_LP.zip       100%[===================>]  17.19K  --.-KB/s    in 0.02s
#
# 2020-06-08 15:52:58 (770 KB/s) - ‘yolov3_LP.zip’ saved [17600/17600]
#
# warning:  stripped absolute path spec from /
# mapname:  conversion of  failed

# %% [markdown]
# ## 3. Train the Model

# %% [markdown]
# Execute following command to start model training, by specifying
# 1. path to the setup file,
# 1. path to config file,
# 1. path to pretrained convolutional weights file
#
# We are  passing some flags such as,
# - `dont_show` to prevent displaying the graphs.
# Since `Colab` does not support, this flag will avoid code crashing. However you can display the graphs if you run this notebook on your local system.
# - `map` - to calculate mAP - mean average precision for the test data specified by `data_test.txt` file.

# %%
# !./darknet detector train yolov3-LP-setup.data yolov3-LP-train.cfg darknet53.conv.74  -dont_show -map 2> train_log.txt
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
#  total_bbox = 47075, rewritten_bbox = 0.000000 %
#  total_bbox = 47078, rewritten_bbox = 0.000000 %
#  total_bbox = 47080, rewritten_bbox = 0.000000 %
#  total_bbox = 47084, rewritten_bbox = 0.000000 %
#  total_bbox = 47088, rewritten_bbox = 0.000000 %
#  total_bbox = 47092, rewritten_bbox = 0.000000 %
#  total_bbox = 47095, rewritten_bbox = 0.000000 %
#  total_bbox = 47099, rewritten_bbox = 0.000000 %
#  total_bbox = 47103, rewritten_bbox = 0.000000 %
#  total_bbox = 47107, rewritten_bbox = 0.000000 %
#  total_bbox = 47111, rewritten_bbox = 0.000000 %
#  total_bbox = 47115, rewritten_bbox = 0.000000 %
#  total_bbox = 47119, rewritten_bbox = 0.000000 %
#  total_bbox = 47123, rewritten_bbox = 0.000000 %
#  total_bbox = 47127, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 800 iterations)
#  Last accuracy mAP@0.5 = 95.58 %, best = 95.78 %
#  771: 0.069090, 0.072766 avg loss, 0.001000 rate, 3.191358 seconds, 49344 images, 0.425521 hours left
# Loaded: 0.000035 seconds
#  total_bbox = 47131, rewritten_bbox = 0.000000 %
#  total_bbox = 47134, rewritten_bbox = 0.000000 %
#  total_bbox = 47138, rewritten_bbox = 0.000000 %
#  total_bbox = 47142, rewritten_bbox = 0.000000 %
#  total_bbox = 47146, rewritten_bbox = 0.000000 %
#  total_bbox = 47150, rewritten_bbox = 0.000000 %
#  total_bbox = 47154, rewritten_bbox = 0.000000 %
#  total_bbox = 47158, rewritten_bbox = 0.000000 %
#  total_bbox = 47162, rewritten_bbox = 0.000000 %
#  total_bbox = 47166, rewritten_bbox = 0.000000 %
#  total_bbox = 47170, rewritten_bbox = 0.000000 %
#  total_bbox = 47174, rewritten_bbox = 0.000000 %
#  total_bbox = 47178, rewritten_bbox = 0.000000 %
#  total_bbox = 47182, rewritten_bbox = 0.000000 %
#  total_bbox = 47186, rewritten_bbox = 0.000000 %
#  total_bbox = 47190, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 800 iterations)
#  Last accuracy mAP@0.5 = 95.58 %, best = 95.78 %
#  772: 0.137713, 0.079261 avg loss, 0.001000 rate, 3.214682 seconds, 49408 images, 0.423536 hours left
# Loaded: 0.000035 seconds
#  total_bbox = 47194, rewritten_bbox = 0.000000 %
#  total_bbox = 47198, rewritten_bbox = 0.000000 %
#  total_bbox = 47202, rewritten_bbox = 0.000000 %
#  total_bbox = 47206, rewritten_bbox = 0.000000 %
#  total_bbox = 47210, rewritten_bbox = 0.000000 %
#  total_bbox = 47214, rewritten_bbox = 0.000000 %
#  total_bbox = 47218, rewritten_bbox = 0.000000 %
#  total_bbox = 47222, rewritten_bbox = 0.000000 %
#  total_bbox = 47226, rewritten_bbox = 0.000000 %
#  total_bbox = 47230, rewritten_bbox = 0.000000 %
#  total_bbox = 47233, rewritten_bbox = 0.000000 %
#  total_bbox = 47236, rewritten_bbox = 0.000000 %
#  total_bbox = 47240, rewritten_bbox = 0.000000 %
#  total_bbox = 47244, rewritten_bbox = 0.000000 %
#  total_bbox = 47248, rewritten_bbox = 0.000000 %
#  total_bbox = 47251, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 800 iterations)
#  Last accuracy mAP@0.5 = 95.58 %, best = 95.78 %
#  773: 0.080340, 0.079368 avg loss, 0.001000 rate, 3.252776 seconds, 49472 images, 0.421337 hours left
# Loaded: 0.000061 seconds
#  total_bbox = 47255, rewritten_bbox = 0.000000 %
#  total_bbox = 47259, rewritten_bbox = 0.000000 %
#  total_bbox = 47263, rewritten_bbox = 0.000000 %
#  total_bbox = 47267, rewritten_bbox = 0.000000 %
#  total_bbox = 47271, rewritten_bbox = 0.000000 %
#  total_bbox = 47275, rewritten_bbox = 0.000000 %
#  total_bbox = 47279, rewritten_bbox = 0.000000 %
#  total_bbox = 47283, rewritten_bbox = 0.000000 %
#  total_bbox = 47287, rewritten_bbox = 0.000000 %
#  total_bbox = 47291, rewritten_bbox = 0.000000 %
#  total_bbox = 47295, rewritten_bbox = 0.000000 %
#  total_bbox = 47299, rewritten_bbox = 0.000000 %
#  total_bbox = 47303, rewritten_bbox = 0.000000 %
#  total_bbox = 47307, rewritten_bbox = 0.000000 %
#  total_bbox = 47310, rewritten_bbox = 0.000000 %
#  total_bbox = 47314, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 800 iterations)
#  Last accuracy mAP@0.5 = 95.58 %, best = 95.78 %
#  774: 0.088099, 0.080242 avg loss, 0.001000 rate, 3.261176 seconds, 49536 images, 0.419175 hours left
# Loaded: 0.000051 seconds
#  total_bbox = 47318, rewritten_bbox = 0.000000 %
#  total_bbox = 47322, rewritten_bbox = 0.000000 %
#  total_bbox = 47326, rewritten_bbox = 0.000000 %
#  total_bbox = 47328, rewritten_bbox = 0.000000 %
#  total_bbox = 47332, rewritten_bbox = 0.000000 %
#  total_bbox = 47336, rewritten_bbox = 0.000000 %
#  total_bbox = 47340, rewritten_bbox = 0.000000 %
#  total_bbox = 47344, rewritten_bbox = 0.000000 %
#  total_bbox = 47348, rewritten_bbox = 0.000000 %
#  total_bbox = 47351, rewritten_bbox = 0.000000 %
#  total_bbox = 47355, rewritten_bbox = 0.000000 %
#  total_bbox = 47359, rewritten_bbox = 0.000000 %
#  total_bbox = 47361, rewritten_bbox = 0.000000 %
#  total_bbox = 47365, rewritten_bbox = 0.000000 %
#  total_bbox = 47369, rewritten_bbox = 0.000000 %
#  total_bbox = 47373, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 800 iterations)
#  Last accuracy mAP@0.5 = 95.58 %, best = 95.78 %
#  775: 0.120757, 0.084293 avg loss, 0.001000 rate, 3.214503 seconds, 49600 images, 0.417030 hours left
# Loaded: 0.000151 seconds
#  total_bbox = 47377, rewritten_bbox = 0.000000 %
#  total_bbox = 47379, rewritten_bbox = 0.000000 %
#  total_bbox = 47383, rewritten_bbox = 0.000000 %
#  total_bbox = 47386, rewritten_bbox = 0.000000 %
#  total_bbox = 47390, rewritten_bbox = 0.000000 %
#  total_bbox = 47394, rewritten_bbox = 0.000000 %
#  total_bbox = 47397, rewritten_bbox = 0.000000 %
#  total_bbox = 47401, rewritten_bbox = 0.000000 %
#  total_bbox = 47405, rewritten_bbox = 0.000000 %
#  total_bbox = 47409, rewritten_bbox = 0.000000 %
#  total_bbox = 47413, rewritten_bbox = 0.000000 %
#  total_bbox = 47417, rewritten_bbox = 0.000000 %
#  total_bbox = 47421, rewritten_bbox = 0.000000 %
#  total_bbox = 47425, rewritten_bbox = 0.000000 %
#  total_bbox = 47429, rewritten_bbox = 0.000000 %
#  total_bbox = 47433, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 800 iterations)
#  Last accuracy mAP@0.5 = 95.58 %, best = 95.78 %
#  776: 0.126876, 0.088551 avg loss, 0.001000 rate, 3.222705 seconds, 49664 images, 0.414869 hours left
# Loaded: 0.000044 seconds
#  total_bbox = 47437, rewritten_bbox = 0.000000 %
#  total_bbox = 47441, rewritten_bbox = 0.000000 %
#  total_bbox = 47445, rewritten_bbox = 0.000000 %
#  total_bbox = 47449, rewritten_bbox = 0.000000 %
#  total_bbox = 47452, rewritten_bbox = 0.000000 %
#  total_bbox = 47456, rewritten_bbox = 0.000000 %
#  total_bbox = 47460, rewritten_bbox = 0.000000 %
#  total_bbox = 47464, rewritten_bbox = 0.000000 %
#  total_bbox = 47467, rewritten_bbox = 0.000000 %
#  total_bbox = 47471, rewritten_bbox = 0.000000 %
#  total_bbox = 47475, rewritten_bbox = 0.000000 %
#  total_bbox = 47479, rewritten_bbox = 0.000000 %
#  total_bbox = 47483, rewritten_bbox = 0.000000 %
#  total_bbox = 47487, rewritten_bbox = 0.000000 %
#  total_bbox = 47491, rewritten_bbox = 0.000000 %
#  total_bbox = 47494, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 800 iterations)
#  Last accuracy mAP@0.5 = 95.58 %, best = 95.78 %
#  777: 0.062411, 0.085937 avg loss, 0.001000 rate, 3.249620 seconds, 49728 images, 0.412726 hours left
# Loaded: 0.000059 seconds
#  total_bbox = 47498, rewritten_bbox = 0.000000 %
#  total_bbox = 47502, rewritten_bbox = 0.000000 %
#  total_bbox = 47506, rewritten_bbox = 0.000000 %
#  total_bbox = 47510, rewritten_bbox = 0.000000 %
#  total_bbox = 47514, rewritten_bbox = 0.000000 %
#  total_bbox = 47518, rewritten_bbox = 0.000000 %
#  total_bbox = 47522, rewritten_bbox = 0.000000 %
#  total_bbox = 47524, rewritten_bbox = 0.000000 %
#  total_bbox = 47528, rewritten_bbox = 0.000000 %
#  total_bbox = 47532, rewritten_bbox = 0.000000 %
#  total_bbox = 47536, rewritten_bbox = 0.000000 %
#  total_bbox = 47540, rewritten_bbox = 0.000000 %
#  total_bbox = 47544, rewritten_bbox = 0.000000 %
#  total_bbox = 47548, rewritten_bbox = 0.000000 %
#  total_bbox = 47552, rewritten_bbox = 0.000000 %
#  total_bbox = 47556, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 800 iterations)
#  Last accuracy mAP@0.5 = 95.58 %, best = 95.78 %
#  778: 0.044968, 0.081840 avg loss, 0.001000 rate, 3.243885 seconds, 49792 images, 0.410611 hours left
# Loaded: 0.000039 seconds
#  total_bbox = 47560, rewritten_bbox = 0.000000 %
#  total_bbox = 47564, rewritten_bbox = 0.000000 %
#  total_bbox = 47567, rewritten_bbox = 0.000000 %
#  total_bbox = 47571, rewritten_bbox = 0.000000 %
#  total_bbox = 47574, rewritten_bbox = 0.000000 %
#  total_bbox = 47578, rewritten_bbox = 0.000000 %
#  total_bbox = 47582, rewritten_bbox = 0.000000 %
#  total_bbox = 47586, rewritten_bbox = 0.000000 %
#  total_bbox = 47590, rewritten_bbox = 0.000000 %
#  total_bbox = 47594, rewritten_bbox = 0.000000 %
#  total_bbox = 47598, rewritten_bbox = 0.000000 %
#  total_bbox = 47602, rewritten_bbox = 0.000000 %
#  total_bbox = 47606, rewritten_bbox = 0.000000 %
#  total_bbox = 47610, rewritten_bbox = 0.000000 %
#  total_bbox = 47613, rewritten_bbox = 0.000000 %
#  total_bbox = 47617, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 800 iterations)
#  Last accuracy mAP@0.5 = 95.58 %, best = 95.78 %
#  779: 0.061893, 0.079846 avg loss, 0.001000 rate, 3.281121 seconds, 49856 images, 0.408506 hours left
# Loaded: 0.000042 seconds
#  total_bbox = 47621, rewritten_bbox = 0.000000 %
#  total_bbox = 47625, rewritten_bbox = 0.000000 %
#  total_bbox = 47627, rewritten_bbox = 0.000000 %
#  total_bbox = 47631, rewritten_bbox = 0.000000 %
#  total_bbox = 47635, rewritten_bbox = 0.000000 %
#  total_bbox = 47639, rewritten_bbox = 0.000000 %
#  total_bbox = 47643, rewritten_bbox = 0.000000 %
#  total_bbox = 47647, rewritten_bbox = 0.000000 %
#  total_bbox = 47651, rewritten_bbox = 0.000000 %
#  total_bbox = 47655, rewritten_bbox = 0.000000 %
#  total_bbox = 47659, rewritten_bbox = 0.000000 %
#  total_bbox = 47663, rewritten_bbox = 0.000000 %
#  total_bbox = 47667, rewritten_bbox = 0.000000 %
#  total_bbox = 47671, rewritten_bbox = 0.000000 %
#  total_bbox = 47674, rewritten_bbox = 0.000000 %
#  total_bbox = 47678, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 800 iterations)
#  Last accuracy mAP@0.5 = 95.58 %, best = 95.78 %
#  780: 0.086189, 0.080480 avg loss, 0.001000 rate, 3.223624 seconds, 49920 images, 0.406435 hours left
# Resizing, random_coef = 1.40
#
#  544 x 544
#  try to allocate additional workspace_size = 85.23 MB
#  CUDA allocate done!
# Loaded: 0.000072 seconds
#  total_bbox = 47682, rewritten_bbox = 0.000000 %
#  total_bbox = 47685, rewritten_bbox = 0.000000 %
#  total_bbox = 47689, rewritten_bbox = 0.000000 %
#  total_bbox = 47693, rewritten_bbox = 0.000000 %
#  total_bbox = 47697, rewritten_bbox = 0.000000 %
#  total_bbox = 47701, rewritten_bbox = 0.000000 %
#  total_bbox = 47705, rewritten_bbox = 0.000000 %
#  total_bbox = 47709, rewritten_bbox = 0.000000 %
#  total_bbox = 47713, rewritten_bbox = 0.000000 %
#  total_bbox = 47716, rewritten_bbox = 0.000000 %
#  total_bbox = 47720, rewritten_bbox = 0.000000 %
#  total_bbox = 47723, rewritten_bbox = 0.000000 %
#  total_bbox = 47727, rewritten_bbox = 0.000000 %
#  total_bbox = 47731, rewritten_bbox = 0.000000 %
#  total_bbox = 47735, rewritten_bbox = 0.000000 %
#  total_bbox = 47739, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 800 iterations)
#  Last accuracy mAP@0.5 = 95.58 %, best = 95.78 %
#  781: 0.066671, 0.079099 avg loss, 0.001000 rate, 5.998166 seconds, 49984 images, 0.404341 hours left
# Loaded: 0.000074 seconds
#  total_bbox = 47743, rewritten_bbox = 0.000000 %
#  total_bbox = 47747, rewritten_bbox = 0.000000 %
#  total_bbox = 47750, rewritten_bbox = 0.000000 %
#  total_bbox = 47754, rewritten_bbox = 0.000000 %
#  total_bbox = 47758, rewritten_bbox = 0.000000 %
#  total_bbox = 47762, rewritten_bbox = 0.000000 %
#  total_bbox = 47765, rewritten_bbox = 0.000000 %
#  total_bbox = 47769, rewritten_bbox = 0.000000 %
#  total_bbox = 47772, rewritten_bbox = 0.000000 %
#  total_bbox = 47776, rewritten_bbox = 0.000000 %
#  total_bbox = 47780, rewritten_bbox = 0.000000 %
#  total_bbox = 47784, rewritten_bbox = 0.000000 %
#  total_bbox = 47788, rewritten_bbox = 0.000000 %
#  total_bbox = 47792, rewritten_bbox = 0.000000 %
#  total_bbox = 47796, rewritten_bbox = 0.000000 %
#  total_bbox = 47799, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 800 iterations)
#  Last accuracy mAP@0.5 = 95.58 %, best = 95.78 %
#  782: 0.095196, 0.080709 avg loss, 0.001000 rate, 6.181602 seconds, 50048 images, 0.403946 hours left
# Loaded: 0.000043 seconds
#  total_bbox = 47803, rewritten_bbox = 0.000000 %
#  total_bbox = 47807, rewritten_bbox = 0.000000 %
#  total_bbox = 47810, rewritten_bbox = 0.000000 %
#  total_bbox = 47813, rewritten_bbox = 0.000000 %
#  total_bbox = 47817, rewritten_bbox = 0.000000 %
#  total_bbox = 47821, rewritten_bbox = 0.000000 %
#  total_bbox = 47825, rewritten_bbox = 0.000000 %
#  total_bbox = 47828, rewritten_bbox = 0.000000 %
#  total_bbox = 47831, rewritten_bbox = 0.000000 %
#  total_bbox = 47835, rewritten_bbox = 0.000000 %
#  total_bbox = 47839, rewritten_bbox = 0.000000 %
#  total_bbox = 47843, rewritten_bbox = 0.000000 %
#  total_bbox = 47847, rewritten_bbox = 0.000000 %
#  total_bbox = 47851, rewritten_bbox = 0.000000 %
#  total_bbox = 47854, rewritten_bbox = 0.000000 %
#  total_bbox = 47857, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 800 iterations)
#  Last accuracy mAP@0.5 = 95.58 %, best = 95.78 %
#  783: 0.055383, 0.078176 avg loss, 0.001000 rate, 6.068604 seconds, 50112 images, 0.403650 hours left
# Loaded: 0.000080 seconds
#  total_bbox = 47861, rewritten_bbox = 0.000000 %
#  total_bbox = 47864, rewritten_bbox = 0.000000 %
#  total_bbox = 47868, rewritten_bbox = 0.000000 %
#  total_bbox = 47871, rewritten_bbox = 0.000000 %
#  total_bbox = 47874, rewritten_bbox = 0.000000 %
#  total_bbox = 47878, rewritten_bbox = 0.000000 %
#  total_bbox = 47882, rewritten_bbox = 0.000000 %
#  total_bbox = 47886, rewritten_bbox = 0.000000 %
#  total_bbox = 47890, rewritten_bbox = 0.000000 %
#  total_bbox = 47894, rewritten_bbox = 0.000000 %
#  total_bbox = 47897, rewritten_bbox = 0.000000 %
#  total_bbox = 47900, rewritten_bbox = 0.000000 %
#  total_bbox = 47904, rewritten_bbox = 0.000000 %
#  total_bbox = 47908, rewritten_bbox = 0.000000 %
#  total_bbox = 47912, rewritten_bbox = 0.000000 %
#  total_bbox = 47916, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 800 iterations)
#  Last accuracy mAP@0.5 = 95.58 %, best = 95.78 %
#  784: 0.062912, 0.076650 avg loss, 0.001000 rate, 6.119183 seconds, 50176 images, 0.403272 hours left
# Loaded: 0.000052 seconds
#  total_bbox = 47920, rewritten_bbox = 0.000000 %
#  total_bbox = 47924, rewritten_bbox = 0.000000 %
#  total_bbox = 47928, rewritten_bbox = 0.000000 %
#  total_bbox = 47932, rewritten_bbox = 0.000000 %
#  total_bbox = 47936, rewritten_bbox = 0.000000 %
#  total_bbox = 47940, rewritten_bbox = 0.000000 %
#  total_bbox = 47943, rewritten_bbox = 0.000000 %
#  total_bbox = 47946, rewritten_bbox = 0.000000 %
#  total_bbox = 47950, rewritten_bbox = 0.000000 %
#  total_bbox = 47954, rewritten_bbox = 0.000000 %
#  total_bbox = 47956, rewritten_bbox = 0.000000 %
#  total_bbox = 47960, rewritten_bbox = 0.000000 %
#  total_bbox = 47964, rewritten_bbox = 0.000000 %
#  total_bbox = 47968, rewritten_bbox = 0.000000 %
#  total_bbox = 47972, rewritten_bbox = 0.000000 %
#  total_bbox = 47976, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 800 iterations)
#  Last accuracy mAP@0.5 = 95.58 %, best = 95.78 %
#  785: 0.071257, 0.076110 avg loss, 0.001000 rate, 6.171687 seconds, 50240 images, 0.402910 hours left
# Loaded: 0.000063 seconds
#  total_bbox = 47980, rewritten_bbox = 0.000000 %
#  total_bbox = 47984, rewritten_bbox = 0.000000 %
#  total_bbox = 47988, rewritten_bbox = 0.000000 %
#  total_bbox = 47992, rewritten_bbox = 0.000000 %
#  total_bbox = 47996, rewritten_bbox = 0.000000 %
#  total_bbox = 48000, rewritten_bbox = 0.000000 %
#  total_bbox = 48004, rewritten_bbox = 0.000000 %
#  total_bbox = 48008, rewritten_bbox = 0.000000 %
#  total_bbox = 48012, rewritten_bbox = 0.000000 %
#  total_bbox = 48016, rewritten_bbox = 0.000000 %
#  total_bbox = 48019, rewritten_bbox = 0.000000 %
#  total_bbox = 48023, rewritten_bbox = 0.000000 %
#  total_bbox = 48026, rewritten_bbox = 0.000000 %
#  total_bbox = 48030, rewritten_bbox = 0.000000 %
#  total_bbox = 48034, rewritten_bbox = 0.000000 %
#  total_bbox = 48037, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 800 iterations)
#  Last accuracy mAP@0.5 = 95.58 %, best = 95.78 %
#  786: 0.054518, 0.073951 avg loss, 0.001000 rate, 6.183165 seconds, 50304 images, 0.402567 hours left
# Loaded: 0.000110 seconds
#  total_bbox = 48041, rewritten_bbox = 0.000000 %
#  total_bbox = 48044, rewritten_bbox = 0.000000 %
#  total_bbox = 48048, rewritten_bbox = 0.000000 %
#  total_bbox = 48052, rewritten_bbox = 0.000000 %
#  total_bbox = 48056, rewritten_bbox = 0.000000 %
#  total_bbox = 48060, rewritten_bbox = 0.000000 %
#  total_bbox = 48064, rewritten_bbox = 0.000000 %
#  total_bbox = 48066, rewritten_bbox = 0.000000 %
#  total_bbox = 48070, rewritten_bbox = 0.000000 %
#  total_bbox = 48073, rewritten_bbox = 0.000000 %
#  total_bbox = 48077, rewritten_bbox = 0.000000 %
#  total_bbox = 48081, rewritten_bbox = 0.000000 %
#  total_bbox = 48085, rewritten_bbox = 0.000000 %
#  total_bbox = 48089, rewritten_bbox = 0.000000 %
#  total_bbox = 48093, rewritten_bbox = 0.000000 %
#  total_bbox = 48096, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 800 iterations)
#  Last accuracy mAP@0.5 = 95.58 %, best = 95.78 %
#  787: 0.050205, 0.071577 avg loss, 0.001000 rate, 6.167149 seconds, 50368 images, 0.402217 hours left
# Loaded: 0.000088 seconds
#  total_bbox = 48100, rewritten_bbox = 0.000000 %
#  total_bbox = 48104, rewritten_bbox = 0.000000 %
#  total_bbox = 48108, rewritten_bbox = 0.000000 %
#  total_bbox = 48112, rewritten_bbox = 0.000000 %
#  total_bbox = 48116, rewritten_bbox = 0.000000 %
#  total_bbox = 48120, rewritten_bbox = 0.000000 %
#  total_bbox = 48123, rewritten_bbox = 0.000000 %
#  total_bbox = 48127, rewritten_bbox = 0.000000 %
#  total_bbox = 48131, rewritten_bbox = 0.000000 %
#  total_bbox = 48135, rewritten_bbox = 0.000000 %
#  total_bbox = 48139, rewritten_bbox = 0.000000 %
#  total_bbox = 48143, rewritten_bbox = 0.000000 %
#  total_bbox = 48147, rewritten_bbox = 0.000000 %
#  total_bbox = 48151, rewritten_bbox = 0.000000 %
#  total_bbox = 48154, rewritten_bbox = 0.000000 %
#  total_bbox = 48158, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 800 iterations)
#  Last accuracy mAP@0.5 = 95.58 %, best = 95.78 %
#  788: 0.066115, 0.071030 avg loss, 0.001000 rate, 6.183566 seconds, 50432 images, 0.401844 hours left
# Loaded: 0.000060 seconds
#  total_bbox = 48162, rewritten_bbox = 0.000000 %
#  total_bbox = 48166, rewritten_bbox = 0.000000 %
#  total_bbox = 48170, rewritten_bbox = 0.000000 %
#  total_bbox = 48174, rewritten_bbox = 0.000000 %
#  total_bbox = 48177, rewritten_bbox = 0.000000 %
#  total_bbox = 48181, rewritten_bbox = 0.000000 %
#  total_bbox = 48184, rewritten_bbox = 0.000000 %
#  total_bbox = 48188, rewritten_bbox = 0.000000 %
#  total_bbox = 48192, rewritten_bbox = 0.000000 %
#  total_bbox = 48196, rewritten_bbox = 0.000000 %
#  total_bbox = 48200, rewritten_bbox = 0.000000 %
#  total_bbox = 48204, rewritten_bbox = 0.000000 %
#  total_bbox = 48208, rewritten_bbox = 0.000000 %
#  total_bbox = 48212, rewritten_bbox = 0.000000 %
#  total_bbox = 48216, rewritten_bbox = 0.000000 %
#  total_bbox = 48220, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 800 iterations)
#  Last accuracy mAP@0.5 = 95.58 %, best = 95.78 %
#  789: 0.078264, 0.071754 avg loss, 0.001000 rate, 6.119300 seconds, 50496 images, 0.401467 hours left
# Loaded: 0.000043 seconds
#  total_bbox = 48224, rewritten_bbox = 0.000000 %
#  total_bbox = 48228, rewritten_bbox = 0.000000 %
#  total_bbox = 48230, rewritten_bbox = 0.000000 %
#  total_bbox = 48233, rewritten_bbox = 0.000000 %
#  total_bbox = 48236, rewritten_bbox = 0.000000 %
#  total_bbox = 48240, rewritten_bbox = 0.000000 %
#  total_bbox = 48244, rewritten_bbox = 0.000000 %
#  total_bbox = 48248, rewritten_bbox = 0.000000 %
#  total_bbox = 48252, rewritten_bbox = 0.000000 %
#  total_bbox = 48256, rewritten_bbox = 0.000000 %
#  total_bbox = 48260, rewritten_bbox = 0.000000 %
#  total_bbox = 48264, rewritten_bbox = 0.000000 %
#  total_bbox = 48267, rewritten_bbox = 0.000000 %
#  total_bbox = 48270, rewritten_bbox = 0.000000 %
#  total_bbox = 48274, rewritten_bbox = 0.000000 %
#  total_bbox = 48278, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 800 iterations)
#  Last accuracy mAP@0.5 = 95.58 %, best = 95.78 %
#  790: 0.048114, 0.069390 avg loss, 0.001000 rate, 6.159857 seconds, 50560 images, 0.401039 hours left
# Resizing, random_coef = 1.40
#
#  384 x 384
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.000049 seconds
#  total_bbox = 48282, rewritten_bbox = 0.000000 %
#  total_bbox = 48285, rewritten_bbox = 0.000000 %
#  total_bbox = 48289, rewritten_bbox = 0.000000 %
#  total_bbox = 48293, rewritten_bbox = 0.000000 %
#  total_bbox = 48297, rewritten_bbox = 0.000000 %
#  total_bbox = 48301, rewritten_bbox = 0.000000 %
#  total_bbox = 48305, rewritten_bbox = 0.000000 %
#  total_bbox = 48309, rewritten_bbox = 0.000000 %
#  total_bbox = 48313, rewritten_bbox = 0.000000 %
#  total_bbox = 48317, rewritten_bbox = 0.000000 %
#  total_bbox = 48320, rewritten_bbox = 0.000000 %
#  total_bbox = 48324, rewritten_bbox = 0.000000 %
#  total_bbox = 48328, rewritten_bbox = 0.000000 %
#  total_bbox = 48332, rewritten_bbox = 0.000000 %
#  total_bbox = 48336, rewritten_bbox = 0.000000 %
#  total_bbox = 48339, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 800 iterations)
#  Last accuracy mAP@0.5 = 95.58 %, best = 95.78 %
#  791: 0.079668, 0.070418 avg loss, 0.001000 rate, 3.177209 seconds, 50624 images, 0.400622 hours left
# Loaded: 0.000049 seconds
#  total_bbox = 48343, rewritten_bbox = 0.000000 %
#  total_bbox = 48346, rewritten_bbox = 0.000000 %
#  total_bbox = 48350, rewritten_bbox = 0.000000 %
#  total_bbox = 48354, rewritten_bbox = 0.000000 %
#  total_bbox = 48358, rewritten_bbox = 0.000000 %
#  total_bbox = 48362, rewritten_bbox = 0.000000 %
#  total_bbox = 48366, rewritten_bbox = 0.000000 %
#  total_bbox = 48370, rewritten_bbox = 0.000000 %
#  total_bbox = 48374, rewritten_bbox = 0.000000 %
#  total_bbox = 48378, rewritten_bbox = 0.000000 %
#  total_bbox = 48382, rewritten_bbox = 0.000000 %
#  total_bbox = 48386, rewritten_bbox = 0.000000 %
#  total_bbox = 48390, rewritten_bbox = 0.000000 %
#  total_bbox = 48393, rewritten_bbox = 0.000000 %
#  total_bbox = 48397, rewritten_bbox = 0.000000 %
#  total_bbox = 48401, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 800 iterations)
#  Last accuracy mAP@0.5 = 95.58 %, best = 95.78 %
#  792: 0.069413, 0.070317 avg loss, 0.001000 rate, 3.226362 seconds, 50688 images, 0.398460 hours left
# Loaded: 0.000040 seconds
#  total_bbox = 48403, rewritten_bbox = 0.000000 %
#  total_bbox = 48407, rewritten_bbox = 0.000000 %
#  total_bbox = 48411, rewritten_bbox = 0.000000 %
#  total_bbox = 48415, rewritten_bbox = 0.000000 %
#  total_bbox = 48419, rewritten_bbox = 0.000000 %
#  total_bbox = 48423, rewritten_bbox = 0.000000 %
#  total_bbox = 48426, rewritten_bbox = 0.000000 %
#  total_bbox = 48429, rewritten_bbox = 0.000000 %
#  total_bbox = 48433, rewritten_bbox = 0.000000 %
#  total_bbox = 48437, rewritten_bbox = 0.000000 %
#  total_bbox = 48441, rewritten_bbox = 0.000000 %
#  total_bbox = 48445, rewritten_bbox = 0.000000 %
#  total_bbox = 48449, rewritten_bbox = 0.000000 %
#  total_bbox = 48453, rewritten_bbox = 0.000000 %
#  total_bbox = 48456, rewritten_bbox = 0.000000 %
#  total_bbox = 48460, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 800 iterations)
#  Last accuracy mAP@0.5 = 95.58 %, best = 95.78 %
#  793: 0.061396, 0.069425 avg loss, 0.001000 rate, 3.246144 seconds, 50752 images, 0.396340 hours left
# Loaded: 0.000048 seconds
#  total_bbox = 48464, rewritten_bbox = 0.000000 %
#  total_bbox = 48468, rewritten_bbox = 0.000000 %
#  total_bbox = 48472, rewritten_bbox = 0.000000 %
#  total_bbox = 48476, rewritten_bbox = 0.000000 %
#  total_bbox = 48480, rewritten_bbox = 0.000000 %
#  total_bbox = 48484, rewritten_bbox = 0.000000 %
#  total_bbox = 48486, rewritten_bbox = 0.000000 %
#  total_bbox = 48490, rewritten_bbox = 0.000000 %
#  total_bbox = 48494, rewritten_bbox = 0.000000 %
#  total_bbox = 48498, rewritten_bbox = 0.000000 %
#  total_bbox = 48501, rewritten_bbox = 0.000000 %
#  total_bbox = 48505, rewritten_bbox = 0.000000 %
#  total_bbox = 48509, rewritten_bbox = 0.000000 %
#  total_bbox = 48513, rewritten_bbox = 0.000000 %
#  total_bbox = 48516, rewritten_bbox = 0.000000 %
#  total_bbox = 48520, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 800 iterations)
#  Last accuracy mAP@0.5 = 95.58 %, best = 95.78 %
#  794: 0.096866, 0.072169 avg loss, 0.001000 rate, 3.204578 seconds, 50816 images, 0.394243 hours left
# Loaded: 0.000039 seconds
#  total_bbox = 48524, rewritten_bbox = 0.000000 %
#  total_bbox = 48528, rewritten_bbox = 0.000000 %
#  total_bbox = 48531, rewritten_bbox = 0.000000 %
#  total_bbox = 48533, rewritten_bbox = 0.000000 %
#  total_bbox = 48537, rewritten_bbox = 0.000000 %
#  total_bbox = 48541, rewritten_bbox = 0.000000 %
#  total_bbox = 48545, rewritten_bbox = 0.000000 %
#  total_bbox = 48549, rewritten_bbox = 0.000000 %
#  total_bbox = 48553, rewritten_bbox = 0.000000 %
#  total_bbox = 48557, rewritten_bbox = 0.000000 %
#  total_bbox = 48561, rewritten_bbox = 0.000000 %
#  total_bbox = 48565, rewritten_bbox = 0.000000 %
#  total_bbox = 48568, rewritten_bbox = 0.000000 %
#  total_bbox = 48572, rewritten_bbox = 0.000000 %
#  total_bbox = 48576, rewritten_bbox = 0.000000 %
#  total_bbox = 48579, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 800 iterations)
#  Last accuracy mAP@0.5 = 95.58 %, best = 95.78 %
#  795: 0.105325, 0.075485 avg loss, 0.001000 rate, 3.233011 seconds, 50880 images, 0.392134 hours left
# Loaded: 0.000045 seconds
#  total_bbox = 48583, rewritten_bbox = 0.000000 %
#  total_bbox = 48587, rewritten_bbox = 0.000000 %
#  total_bbox = 48591, rewritten_bbox = 0.000000 %
#  total_bbox = 48595, rewritten_bbox = 0.000000 %
#  total_bbox = 48598, rewritten_bbox = 0.000000 %
#  total_bbox = 48602, rewritten_bbox = 0.000000 %
#  total_bbox = 48606, rewritten_bbox = 0.000000 %
#  total_bbox = 48609, rewritten_bbox = 0.000000 %
#  total_bbox = 48613, rewritten_bbox = 0.000000 %
#  total_bbox = 48617, rewritten_bbox = 0.000000 %
#  total_bbox = 48618, rewritten_bbox = 0.000000 %
#  total_bbox = 48622, rewritten_bbox = 0.000000 %
#  total_bbox = 48626, rewritten_bbox = 0.000000 %
#  total_bbox = 48630, rewritten_bbox = 0.000000 %
#  total_bbox = 48634, rewritten_bbox = 0.000000 %
#  total_bbox = 48638, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 800 iterations)
#  Last accuracy mAP@0.5 = 95.58 %, best = 95.78 %
#  796: 0.068483, 0.074785 avg loss, 0.001000 rate, 3.270802 seconds, 50944 images, 0.390054 hours left
# Loaded: 0.000039 seconds
#  total_bbox = 48642, rewritten_bbox = 0.000000 %
#  total_bbox = 48646, rewritten_bbox = 0.000000 %
#  total_bbox = 48650, rewritten_bbox = 0.000000 %
#  total_bbox = 48654, rewritten_bbox = 0.000000 %
#  total_bbox = 48658, rewritten_bbox = 0.000000 %
#  total_bbox = 48662, rewritten_bbox = 0.000000 %
#  total_bbox = 48665, rewritten_bbox = 0.000000 %
#  total_bbox = 48669, rewritten_bbox = 0.000000 %
#  total_bbox = 48673, rewritten_bbox = 0.000000 %
#  total_bbox = 48676, rewritten_bbox = 0.000000 %
#  total_bbox = 48680, rewritten_bbox = 0.000000 %
#  total_bbox = 48684, rewritten_bbox = 0.000000 %
#  total_bbox = 48688, rewritten_bbox = 0.000000 %
#  total_bbox = 48692, rewritten_bbox = 0.000000 %
#  total_bbox = 48695, rewritten_bbox = 0.000000 %
#  total_bbox = 48699, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 800 iterations)
#  Last accuracy mAP@0.5 = 95.58 %, best = 95.78 %
#  797: 0.070566, 0.074363 avg loss, 0.001000 rate, 3.255627 seconds, 51008 images, 0.388007 hours left
# Loaded: 0.000040 seconds
#  total_bbox = 48703, rewritten_bbox = 0.000000 %
#  total_bbox = 48707, rewritten_bbox = 0.000000 %
#  total_bbox = 48711, rewritten_bbox = 0.000000 %
#  total_bbox = 48715, rewritten_bbox = 0.000000 %
#  total_bbox = 48719, rewritten_bbox = 0.000000 %
#  total_bbox = 48723, rewritten_bbox = 0.000000 %
#  total_bbox = 48727, rewritten_bbox = 0.000000 %
#  total_bbox = 48730, rewritten_bbox = 0.000000 %
#  total_bbox = 48733, rewritten_bbox = 0.000000 %
#  total_bbox = 48737, rewritten_bbox = 0.000000 %
#  total_bbox = 48741, rewritten_bbox = 0.000000 %
#  total_bbox = 48745, rewritten_bbox = 0.000000 %
#  total_bbox = 48749, rewritten_bbox = 0.000000 %
#  total_bbox = 48753, rewritten_bbox = 0.000000 %
#  total_bbox = 48757, rewritten_bbox = 0.000000 %
#  total_bbox = 48760, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 800 iterations)
#  Last accuracy mAP@0.5 = 95.58 %, best = 95.78 %
#  798: 0.074207, 0.074347 avg loss, 0.001000 rate, 3.223158 seconds, 51072 images, 0.385963 hours left
# Loaded: 0.000081 seconds
#  total_bbox = 48764, rewritten_bbox = 0.000000 %
#  total_bbox = 48768, rewritten_bbox = 0.000000 %
#  total_bbox = 48772, rewritten_bbox = 0.000000 %
#  total_bbox = 48776, rewritten_bbox = 0.000000 %
#  total_bbox = 48779, rewritten_bbox = 0.000000 %
#  total_bbox = 48782, rewritten_bbox = 0.000000 %
#  total_bbox = 48786, rewritten_bbox = 0.000000 %
#  total_bbox = 48789, rewritten_bbox = 0.000000 %
#  total_bbox = 48793, rewritten_bbox = 0.000000 %
#  total_bbox = 48796, rewritten_bbox = 0.000000 %
#  total_bbox = 48799, rewritten_bbox = 0.000000 %
#  total_bbox = 48802, rewritten_bbox = 0.000000 %
#  total_bbox = 48805, rewritten_bbox = 0.000000 %
#  total_bbox = 48809, rewritten_bbox = 0.000000 %
#  total_bbox = 48813, rewritten_bbox = 0.000000 %
#  total_bbox = 48817, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 800 iterations)
#  Last accuracy mAP@0.5 = 95.58 %, best = 95.78 %
#  799: 0.053062, 0.072219 avg loss, 0.001000 rate, 3.270249 seconds, 51136 images, 0.383912 hours left
# Loaded: 0.000034 seconds
#  total_bbox = 48821, rewritten_bbox = 0.000000 %
#  total_bbox = 48824, rewritten_bbox = 0.000000 %
#  total_bbox = 48828, rewritten_bbox = 0.000000 %
#  total_bbox = 48832, rewritten_bbox = 0.000000 %
#  total_bbox = 48835, rewritten_bbox = 0.000000 %
#  total_bbox = 48839, rewritten_bbox = 0.000000 %
#  total_bbox = 48843, rewritten_bbox = 0.000000 %
#  total_bbox = 48847, rewritten_bbox = 0.000000 %
#  total_bbox = 48851, rewritten_bbox = 0.000000 %
#  total_bbox = 48854, rewritten_bbox = 0.000000 %
#  total_bbox = 48858, rewritten_bbox = 0.000000 %
#  total_bbox = 48862, rewritten_bbox = 0.000000 %
#  total_bbox = 48865, rewritten_bbox = 0.000000 %
#  total_bbox = 48869, rewritten_bbox = 0.000000 %
#  total_bbox = 48872, rewritten_bbox = 0.000000 %
#  total_bbox = 48876, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 800 iterations)
#  Last accuracy mAP@0.5 = 95.58 %, best = 95.78 %
#  800: 0.079569, 0.072954 avg loss, 0.000100 rate, 3.221186 seconds, 51200 images, 0.381899 hours left
# Resizing to initial size: 416 x 416  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
#
#  calculation mAP (mean average precision)...
#
#  detections_count = 105, unique_truth_count = 69
# class_id = 0, name = License Plate, ap = 95.84%   	 (TP = 68, FP = 8)
#
#  for conf_thresh = 0.25, precision = 0.89, recall = 0.99, F1-score = 0.94
#  for conf_thresh = 0.25, TP = 68, FP = 8, FN = 1, average IoU = 72.18 %
#
#  IoU threshold = 50 %, used Area-Under-Curve for each unique Recall
#  mean average precision (mAP@0.50) = 0.958354, or 95.84 %
#
# Set -points flag:
#  `-points 101` for MS COCO
#  `-points 11` for PascalVOC 2007 (uncomment `difficult` in voc.data)
#  `-points 0` (AUC) for ImageNet, PascalVOC 2010-2012, your custom dataset
#
#  mean_average_precision (mAP@0.5) = 0.958354
# New best mAP!
# Resizing, random_coef = 1.40
#
#  512 x 512
#  try to allocate additional workspace_size = 75.50 MB
#  CUDA allocate done!
# Loaded: 0.000058 seconds
#  total_bbox = 48879, rewritten_bbox = 0.000000 %
#  total_bbox = 48883, rewritten_bbox = 0.000000 %
#  total_bbox = 48887, rewritten_bbox = 0.000000 %
#  total_bbox = 48891, rewritten_bbox = 0.000000 %
#  total_bbox = 48895, rewritten_bbox = 0.000000 %
#  total_bbox = 48899, rewritten_bbox = 0.000000 %
#  total_bbox = 48903, rewritten_bbox = 0.000000 %
#  total_bbox = 48907, rewritten_bbox = 0.000000 %
#  total_bbox = 48911, rewritten_bbox = 0.000000 %
#  total_bbox = 48915, rewritten_bbox = 0.000000 %
#  total_bbox = 48919, rewritten_bbox = 0.000000 %
#  total_bbox = 48923, rewritten_bbox = 0.000000 %
#  total_bbox = 48927, rewritten_bbox = 0.000000 %
#  total_bbox = 48931, rewritten_bbox = 0.000000 %
#  total_bbox = 48935, rewritten_bbox = 0.000000 %
#  total_bbox = 48939, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 900 iterations)
#  Last accuracy mAP@0.5 = 95.84 %, best = 95.84 %
#  801: 0.102967, 0.075955 avg loss, 0.000100 rate, 5.210247 seconds, 51264 images, 0.382856 hours left
# Loaded: 0.000060 seconds
#  total_bbox = 48943, rewritten_bbox = 0.000000 %
#  total_bbox = 48947, rewritten_bbox = 0.000000 %
#  total_bbox = 48950, rewritten_bbox = 0.000000 %
#  total_bbox = 48954, rewritten_bbox = 0.000000 %
#  total_bbox = 48958, rewritten_bbox = 0.000000 %
#  total_bbox = 48961, rewritten_bbox = 0.000000 %
#  total_bbox = 48965, rewritten_bbox = 0.000000 %
#  total_bbox = 48969, rewritten_bbox = 0.000000 %
#  total_bbox = 48972, rewritten_bbox = 0.000000 %
#  total_bbox = 48975, rewritten_bbox = 0.000000 %
#  total_bbox = 48978, rewritten_bbox = 0.000000 %
#  total_bbox = 48982, rewritten_bbox = 0.000000 %
#  total_bbox = 48986, rewritten_bbox = 0.000000 %
#  total_bbox = 48989, rewritten_bbox = 0.000000 %
#  total_bbox = 48993, rewritten_bbox = 0.000000 %
#  total_bbox = 48997, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 900 iterations)
#  Last accuracy mAP@0.5 = 95.84 %, best = 95.84 %
#  802: 0.074945, 0.075854 avg loss, 0.000100 rate, 5.309829 seconds, 51328 images, 0.381907 hours left
# Loaded: 0.000072 seconds
#  total_bbox = 49001, rewritten_bbox = 0.000000 %
#  total_bbox = 49005, rewritten_bbox = 0.000000 %
#  total_bbox = 49008, rewritten_bbox = 0.000000 %
#  total_bbox = 49012, rewritten_bbox = 0.000000 %
#  total_bbox = 49016, rewritten_bbox = 0.000000 %
#  total_bbox = 49020, rewritten_bbox = 0.000000 %
#  total_bbox = 49024, rewritten_bbox = 0.000000 %
#  total_bbox = 49028, rewritten_bbox = 0.000000 %
#  total_bbox = 49032, rewritten_bbox = 0.000000 %
#  total_bbox = 49036, rewritten_bbox = 0.000000 %
#  total_bbox = 49039, rewritten_bbox = 0.000000 %
#  total_bbox = 49043, rewritten_bbox = 0.000000 %
#  total_bbox = 49047, rewritten_bbox = 0.000000 %
#  total_bbox = 49051, rewritten_bbox = 0.000000 %
#  total_bbox = 49055, rewritten_bbox = 0.000000 %
#  total_bbox = 49059, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 900 iterations)
#  Last accuracy mAP@0.5 = 95.84 %, best = 95.84 %
#  803: 0.091551, 0.077424 avg loss, 0.000100 rate, 5.332629 seconds, 51392 images, 0.381009 hours left
# Loaded: 0.000047 seconds
#  total_bbox = 49063, rewritten_bbox = 0.000000 %
#  total_bbox = 49067, rewritten_bbox = 0.000000 %
#  total_bbox = 49071, rewritten_bbox = 0.000000 %
#  total_bbox = 49075, rewritten_bbox = 0.000000 %
#  total_bbox = 49079, rewritten_bbox = 0.000000 %
#  total_bbox = 49083, rewritten_bbox = 0.000000 %
#  total_bbox = 49086, rewritten_bbox = 0.000000 %
#  total_bbox = 49089, rewritten_bbox = 0.000000 %
#  total_bbox = 49093, rewritten_bbox = 0.000000 %
#  total_bbox = 49097, rewritten_bbox = 0.000000 %
#  total_bbox = 49101, rewritten_bbox = 0.000000 %
#  total_bbox = 49105, rewritten_bbox = 0.000000 %
#  total_bbox = 49109, rewritten_bbox = 0.000000 %
#  total_bbox = 49113, rewritten_bbox = 0.000000 %
#  total_bbox = 49117, rewritten_bbox = 0.000000 %
#  total_bbox = 49120, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 900 iterations)
#  Last accuracy mAP@0.5 = 95.84 %, best = 95.84 %
#  804: 0.073975, 0.077079 avg loss, 0.000100 rate, 5.305903 seconds, 51456 images, 0.380117 hours left
# Loaded: 0.000044 seconds
#  total_bbox = 49124, rewritten_bbox = 0.000000 %
#  total_bbox = 49127, rewritten_bbox = 0.000000 %
#  total_bbox = 49131, rewritten_bbox = 0.000000 %
#  total_bbox = 49135, rewritten_bbox = 0.000000 %
#  total_bbox = 49139, rewritten_bbox = 0.000000 %
#  total_bbox = 49143, rewritten_bbox = 0.000000 %
#  total_bbox = 49146, rewritten_bbox = 0.000000 %
#  total_bbox = 49150, rewritten_bbox = 0.000000 %
#  total_bbox = 49154, rewritten_bbox = 0.000000 %
#  total_bbox = 49157, rewritten_bbox = 0.000000 %
#  total_bbox = 49161, rewritten_bbox = 0.000000 %
#  total_bbox = 49165, rewritten_bbox = 0.000000 %
#  total_bbox = 49169, rewritten_bbox = 0.000000 %
#  total_bbox = 49173, rewritten_bbox = 0.000000 %
#  total_bbox = 49177, rewritten_bbox = 0.000000 %
#  total_bbox = 49181, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 900 iterations)
#  Last accuracy mAP@0.5 = 95.84 %, best = 95.84 %
#  805: 0.099080, 0.079279 avg loss, 0.000100 rate, 5.323724 seconds, 51520 images, 0.379205 hours left
# Loaded: 0.000073 seconds
#  total_bbox = 49184, rewritten_bbox = 0.000000 %
#  total_bbox = 49188, rewritten_bbox = 0.000000 %
#  total_bbox = 49192, rewritten_bbox = 0.000000 %
#  total_bbox = 49195, rewritten_bbox = 0.000000 %
#  total_bbox = 49199, rewritten_bbox = 0.000000 %
#  total_bbox = 49203, rewritten_bbox = 0.000000 %
#  total_bbox = 49207, rewritten_bbox = 0.000000 %
#  total_bbox = 49211, rewritten_bbox = 0.000000 %
#  total_bbox = 49215, rewritten_bbox = 0.000000 %
#  total_bbox = 49218, rewritten_bbox = 0.000000 %
#  total_bbox = 49222, rewritten_bbox = 0.000000 %
#  total_bbox = 49225, rewritten_bbox = 0.000000 %
#  total_bbox = 49229, rewritten_bbox = 0.000000 %
#  total_bbox = 49233, rewritten_bbox = 0.000000 %
#  total_bbox = 49237, rewritten_bbox = 0.000000 %
#  total_bbox = 49241, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 900 iterations)
#  Last accuracy mAP@0.5 = 95.84 %, best = 95.84 %
#  806: 0.060986, 0.077450 avg loss, 0.000100 rate, 5.251423 seconds, 51584 images, 0.378296 hours left
# Loaded: 0.000043 seconds
#  total_bbox = 49244, rewritten_bbox = 0.000000 %
#  total_bbox = 49248, rewritten_bbox = 0.000000 %
#  total_bbox = 49251, rewritten_bbox = 0.000000 %
#  total_bbox = 49255, rewritten_bbox = 0.000000 %
#  total_bbox = 49259, rewritten_bbox = 0.000000 %
#  total_bbox = 49262, rewritten_bbox = 0.000000 %
#  total_bbox = 49266, rewritten_bbox = 0.000000 %
#  total_bbox = 49270, rewritten_bbox = 0.000000 %
#  total_bbox = 49274, rewritten_bbox = 0.000000 %
#  total_bbox = 49278, rewritten_bbox = 0.000000 %
#  total_bbox = 49282, rewritten_bbox = 0.000000 %
#  total_bbox = 49286, rewritten_bbox = 0.000000 %
#  total_bbox = 49290, rewritten_bbox = 0.000000 %
#  total_bbox = 49294, rewritten_bbox = 0.000000 %
#  total_bbox = 49298, rewritten_bbox = 0.000000 %
#  total_bbox = 49300, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 900 iterations)
#  Last accuracy mAP@0.5 = 95.84 %, best = 95.84 %
#  807: 0.047625, 0.074467 avg loss, 0.000100 rate, 5.299521 seconds, 51648 images, 0.377343 hours left
# Loaded: 0.000066 seconds
#  total_bbox = 49304, rewritten_bbox = 0.000000 %
#  total_bbox = 49308, rewritten_bbox = 0.000000 %
#  total_bbox = 49312, rewritten_bbox = 0.000000 %
#  total_bbox = 49316, rewritten_bbox = 0.000000 %
#  total_bbox = 49320, rewritten_bbox = 0.000000 %
#  total_bbox = 49324, rewritten_bbox = 0.000000 %
#  total_bbox = 49327, rewritten_bbox = 0.000000 %
#  total_bbox = 49330, rewritten_bbox = 0.000000 %
#  total_bbox = 49334, rewritten_bbox = 0.000000 %
#  total_bbox = 49338, rewritten_bbox = 0.000000 %
#  total_bbox = 49342, rewritten_bbox = 0.000000 %
#  total_bbox = 49346, rewritten_bbox = 0.000000 %
#  total_bbox = 49350, rewritten_bbox = 0.000000 %
#  total_bbox = 49354, rewritten_bbox = 0.000000 %
#  total_bbox = 49358, rewritten_bbox = 0.000000 %
#  total_bbox = 49362, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 900 iterations)
#  Last accuracy mAP@0.5 = 95.84 %, best = 95.84 %
#  808: 0.077270, 0.074747 avg loss, 0.000100 rate, 5.265794 seconds, 51712 images, 0.376411 hours left
# Loaded: 0.000033 seconds
#  total_bbox = 49366, rewritten_bbox = 0.000000 %
#  total_bbox = 49370, rewritten_bbox = 0.000000 %
#  total_bbox = 49374, rewritten_bbox = 0.000000 %
#  total_bbox = 49378, rewritten_bbox = 0.000000 %
#  total_bbox = 49382, rewritten_bbox = 0.000000 %
#  total_bbox = 49386, rewritten_bbox = 0.000000 %
#  total_bbox = 49390, rewritten_bbox = 0.000000 %
#  total_bbox = 49394, rewritten_bbox = 0.000000 %
#  total_bbox = 49398, rewritten_bbox = 0.000000 %
#  total_bbox = 49400, rewritten_bbox = 0.000000 %
#  total_bbox = 49404, rewritten_bbox = 0.000000 %
#  total_bbox = 49408, rewritten_bbox = 0.000000 %
#  total_bbox = 49412, rewritten_bbox = 0.000000 %
#  total_bbox = 49416, rewritten_bbox = 0.000000 %
#  total_bbox = 49420, rewritten_bbox = 0.000000 %
#  total_bbox = 49423, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 900 iterations)
#  Last accuracy mAP@0.5 = 95.84 %, best = 95.84 %
#  809: 0.066851, 0.073958 avg loss, 0.000100 rate, 5.378978 seconds, 51776 images, 0.375455 hours left
# Loaded: 0.000058 seconds
#  total_bbox = 49427, rewritten_bbox = 0.000000 %
#  total_bbox = 49430, rewritten_bbox = 0.000000 %
#  total_bbox = 49434, rewritten_bbox = 0.000000 %
#  total_bbox = 49438, rewritten_bbox = 0.000000 %
#  total_bbox = 49442, rewritten_bbox = 0.000000 %
#  total_bbox = 49446, rewritten_bbox = 0.000000 %
#  total_bbox = 49450, rewritten_bbox = 0.000000 %
#  total_bbox = 49454, rewritten_bbox = 0.000000 %
#  total_bbox = 49458, rewritten_bbox = 0.000000 %
#  total_bbox = 49462, rewritten_bbox = 0.000000 %
#  total_bbox = 49466, rewritten_bbox = 0.000000 %
#  total_bbox = 49470, rewritten_bbox = 0.000000 %
#  total_bbox = 49474, rewritten_bbox = 0.000000 %
#  total_bbox = 49478, rewritten_bbox = 0.000000 %
#  total_bbox = 49482, rewritten_bbox = 0.000000 %
#  total_bbox = 49486, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 900 iterations)
#  Last accuracy mAP@0.5 = 95.84 %, best = 95.84 %
#  810: 0.052077, 0.071770 avg loss, 0.000100 rate, 5.284233 seconds, 51840 images, 0.374555 hours left
# Resizing, random_coef = 1.40
#
#  416 x 416
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.508269 seconds - performance bottleneck on CPU or Disk HDD/SSD
#  total_bbox = 49490, rewritten_bbox = 0.000000 %
#  total_bbox = 49494, rewritten_bbox = 0.000000 %
#  total_bbox = 49497, rewritten_bbox = 0.000000 %
#  total_bbox = 49501, rewritten_bbox = 0.000000 %
#  total_bbox = 49505, rewritten_bbox = 0.000000 %
#  total_bbox = 49509, rewritten_bbox = 0.000000 %
#  total_bbox = 49513, rewritten_bbox = 0.000000 %
#  total_bbox = 49516, rewritten_bbox = 0.000000 %
#  total_bbox = 49520, rewritten_bbox = 0.000000 %
#  total_bbox = 49524, rewritten_bbox = 0.000000 %
#  total_bbox = 49528, rewritten_bbox = 0.000000 %
#  total_bbox = 49531, rewritten_bbox = 0.000000 %
#  total_bbox = 49535, rewritten_bbox = 0.000000 %
#  total_bbox = 49539, rewritten_bbox = 0.000000 %
#  total_bbox = 49543, rewritten_bbox = 0.000000 %
#  total_bbox = 49547, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 900 iterations)
#  Last accuracy mAP@0.5 = 95.84 %, best = 95.84 %
#  811: 0.110992, 0.075692 avg loss, 0.000100 rate, 3.671317 seconds, 51904 images, 0.373598 hours left
# Loaded: 0.000091 seconds
#  total_bbox = 49551, rewritten_bbox = 0.000000 %
#  total_bbox = 49555, rewritten_bbox = 0.000000 %
#  total_bbox = 49559, rewritten_bbox = 0.000000 %
#  total_bbox = 49563, rewritten_bbox = 0.000000 %
#  total_bbox = 49567, rewritten_bbox = 0.000000 %
#  total_bbox = 49570, rewritten_bbox = 0.000000 %
#  total_bbox = 49574, rewritten_bbox = 0.000000 %
#  total_bbox = 49578, rewritten_bbox = 0.000000 %
#  total_bbox = 49582, rewritten_bbox = 0.000000 %
#  total_bbox = 49586, rewritten_bbox = 0.000000 %
#  total_bbox = 49590, rewritten_bbox = 0.000000 %
#  total_bbox = 49594, rewritten_bbox = 0.000000 %
#  total_bbox = 49597, rewritten_bbox = 0.000000 %
#  total_bbox = 49601, rewritten_bbox = 0.000000 %
#  total_bbox = 49605, rewritten_bbox = 0.000000 %
#  total_bbox = 49609, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 900 iterations)
#  Last accuracy mAP@0.5 = 95.84 %, best = 95.84 %
#  812: 0.091302, 0.077253 avg loss, 0.000100 rate, 3.738620 seconds, 51968 images, 0.372056 hours left
# Loaded: 0.000060 seconds
#  total_bbox = 49613, rewritten_bbox = 0.000000 %
#  total_bbox = 49617, rewritten_bbox = 0.000000 %
#  total_bbox = 49621, rewritten_bbox = 0.000000 %
#  total_bbox = 49625, rewritten_bbox = 0.000000 %
#  total_bbox = 49629, rewritten_bbox = 0.000000 %
#  total_bbox = 49633, rewritten_bbox = 0.000000 %
#  total_bbox = 49637, rewritten_bbox = 0.000000 %
#  total_bbox = 49640, rewritten_bbox = 0.000000 %
#  total_bbox = 49643, rewritten_bbox = 0.000000 %
#  total_bbox = 49647, rewritten_bbox = 0.000000 %
#  total_bbox = 49651, rewritten_bbox = 0.000000 %
#  total_bbox = 49655, rewritten_bbox = 0.000000 %
#  total_bbox = 49659, rewritten_bbox = 0.000000 %
#  total_bbox = 49663, rewritten_bbox = 0.000000 %
#  total_bbox = 49667, rewritten_bbox = 0.000000 %
#  total_bbox = 49671, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 900 iterations)
#  Last accuracy mAP@0.5 = 95.84 %, best = 95.84 %
#  813: 0.068747, 0.076402 avg loss, 0.000100 rate, 3.744853 seconds, 52032 images, 0.370288 hours left
# Loaded: 0.000043 seconds
#  total_bbox = 49675, rewritten_bbox = 0.000000 %
#  total_bbox = 49679, rewritten_bbox = 0.000000 %
#  total_bbox = 49683, rewritten_bbox = 0.000000 %
#  total_bbox = 49687, rewritten_bbox = 0.000000 %
#  total_bbox = 49691, rewritten_bbox = 0.000000 %
#  total_bbox = 49695, rewritten_bbox = 0.000000 %
#  total_bbox = 49699, rewritten_bbox = 0.000000 %
#  total_bbox = 49703, rewritten_bbox = 0.000000 %
#  total_bbox = 49707, rewritten_bbox = 0.000000 %
#  total_bbox = 49711, rewritten_bbox = 0.000000 %
#  total_bbox = 49715, rewritten_bbox = 0.000000 %
#  total_bbox = 49719, rewritten_bbox = 0.000000 %
#  total_bbox = 49723, rewritten_bbox = 0.000000 %
#  total_bbox = 49727, rewritten_bbox = 0.000000 %
#  total_bbox = 49730, rewritten_bbox = 0.000000 %
#  total_bbox = 49734, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 900 iterations)
#  Last accuracy mAP@0.5 = 95.84 %, best = 95.84 %
#  814: 0.049284, 0.073691 avg loss, 0.000100 rate, 3.723478 seconds, 52096 images, 0.368531 hours left
# Loaded: 0.000080 seconds
#  total_bbox = 49738, rewritten_bbox = 0.000000 %
#  total_bbox = 49742, rewritten_bbox = 0.000000 %
#  total_bbox = 49746, rewritten_bbox = 0.000000 %
#  total_bbox = 49750, rewritten_bbox = 0.000000 %
#  total_bbox = 49753, rewritten_bbox = 0.000000 %
#  total_bbox = 49756, rewritten_bbox = 0.000000 %
#  total_bbox = 49760, rewritten_bbox = 0.000000 %
#  total_bbox = 49764, rewritten_bbox = 0.000000 %
#  total_bbox = 49768, rewritten_bbox = 0.000000 %
#  total_bbox = 49772, rewritten_bbox = 0.000000 %
#  total_bbox = 49775, rewritten_bbox = 0.000000 %
#  total_bbox = 49779, rewritten_bbox = 0.000000 %
#  total_bbox = 49783, rewritten_bbox = 0.000000 %
#  total_bbox = 49787, rewritten_bbox = 0.000000 %
#  total_bbox = 49791, rewritten_bbox = 0.000000 %
#  total_bbox = 49794, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 900 iterations)
#  Last accuracy mAP@0.5 = 95.84 %, best = 95.84 %
#  815: 0.050484, 0.071370 avg loss, 0.000100 rate, 3.727370 seconds, 52160 images, 0.366769 hours left
# Loaded: 0.000069 seconds
#  total_bbox = 49798, rewritten_bbox = 0.000000 %
#  total_bbox = 49802, rewritten_bbox = 0.000000 %
#  total_bbox = 49806, rewritten_bbox = 0.000000 %
#  total_bbox = 49810, rewritten_bbox = 0.000000 %
#  total_bbox = 49813, rewritten_bbox = 0.000000 %
#  total_bbox = 49817, rewritten_bbox = 0.000000 %
#  total_bbox = 49821, rewritten_bbox = 0.000000 %
#  total_bbox = 49825, rewritten_bbox = 0.000000 %
#  total_bbox = 49829, rewritten_bbox = 0.000000 %
#  total_bbox = 49833, rewritten_bbox = 0.000000 %
#  total_bbox = 49837, rewritten_bbox = 0.000000 %
#  total_bbox = 49841, rewritten_bbox = 0.000000 %
#  total_bbox = 49845, rewritten_bbox = 0.000000 %
# ...
#  total_bbox = 60194, rewritten_bbox = 0.000000 %
#  total_bbox = 60198, rewritten_bbox = 0.000000 %
#  total_bbox = 60202, rewritten_bbox = 0.000000 %
#  total_bbox = 60205, rewritten_bbox = 0.000000 %
#  total_bbox = 60208, rewritten_bbox = 0.000000 %
#  total_bbox = 60212, rewritten_bbox = 0.000000 %
#  total_bbox = 60215, rewritten_bbox = 0.000000 %
#  total_bbox = 60218, rewritten_bbox = 0.000000 %
#  total_bbox = 60222, rewritten_bbox = 0.000000 %
#  total_bbox = 60226, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 95.68 %, best = 95.84 %
#  986: 0.050355, 0.041603 avg loss, 0.000100 rate, 7.317013 seconds, 63104 images, 0.175720 hours left
# Loaded: 0.000094 seconds
#  total_bbox = 60230, rewritten_bbox = 0.000000 %
#  total_bbox = 60234, rewritten_bbox = 0.000000 %
#  total_bbox = 60238, rewritten_bbox = 0.000000 %
#  total_bbox = 60242, rewritten_bbox = 0.000000 %
#  total_bbox = 60246, rewritten_bbox = 0.000000 %
#  total_bbox = 60249, rewritten_bbox = 0.000000 %
#  total_bbox = 60253, rewritten_bbox = 0.000000 %
#  total_bbox = 60257, rewritten_bbox = 0.000000 %
#  total_bbox = 60261, rewritten_bbox = 0.000000 %
#  total_bbox = 60265, rewritten_bbox = 0.000000 %
#  total_bbox = 60269, rewritten_bbox = 0.000000 %
#  total_bbox = 60273, rewritten_bbox = 0.000000 %
#  total_bbox = 60277, rewritten_bbox = 0.000000 %
#  total_bbox = 60281, rewritten_bbox = 0.000000 %
#  total_bbox = 60285, rewritten_bbox = 0.000000 %
#  total_bbox = 60289, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 95.68 %, best = 95.84 %
#  987: 0.039816, 0.041424 avg loss, 0.000100 rate, 7.376005 seconds, 63168 images, 0.174248 hours left
# Loaded: 0.000059 seconds
#  total_bbox = 60293, rewritten_bbox = 0.000000 %
#  total_bbox = 60297, rewritten_bbox = 0.000000 %
#  total_bbox = 60300, rewritten_bbox = 0.000000 %
#  total_bbox = 60303, rewritten_bbox = 0.000000 %
#  total_bbox = 60306, rewritten_bbox = 0.000000 %
#  total_bbox = 60310, rewritten_bbox = 0.000000 %
#  total_bbox = 60314, rewritten_bbox = 0.000000 %
#  total_bbox = 60318, rewritten_bbox = 0.000000 %
#  total_bbox = 60321, rewritten_bbox = 0.000000 %
#  total_bbox = 60325, rewritten_bbox = 0.000000 %
#  total_bbox = 60328, rewritten_bbox = 0.000000 %
#  total_bbox = 60332, rewritten_bbox = 0.000000 %
#  total_bbox = 60334, rewritten_bbox = 0.000000 %
#  total_bbox = 60338, rewritten_bbox = 0.000000 %
#  total_bbox = 60342, rewritten_bbox = 0.000000 %
#  total_bbox = 60346, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 95.68 %, best = 95.84 %
#  988: 0.037772, 0.041059 avg loss, 0.000100 rate, 7.303485 seconds, 63232 images, 0.172772 hours left
# Loaded: 0.000053 seconds
#  total_bbox = 60348, rewritten_bbox = 0.000000 %
#  total_bbox = 60352, rewritten_bbox = 0.000000 %
#  total_bbox = 60356, rewritten_bbox = 0.000000 %
#  total_bbox = 60360, rewritten_bbox = 0.000000 %
#  total_bbox = 60364, rewritten_bbox = 0.000000 %
#  total_bbox = 60368, rewritten_bbox = 0.000000 %
#  total_bbox = 60372, rewritten_bbox = 0.000000 %
#  total_bbox = 60376, rewritten_bbox = 0.000000 %
#  total_bbox = 60380, rewritten_bbox = 0.000000 %
#  total_bbox = 60384, rewritten_bbox = 0.000000 %
#  total_bbox = 60388, rewritten_bbox = 0.000000 %
#  total_bbox = 60392, rewritten_bbox = 0.000000 %
#  total_bbox = 60395, rewritten_bbox = 0.000000 %
#  total_bbox = 60399, rewritten_bbox = 0.000000 %
#  total_bbox = 60403, rewritten_bbox = 0.000000 %
#  total_bbox = 60407, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 95.68 %, best = 95.84 %
#  989: 0.046302, 0.041583 avg loss, 0.000100 rate, 7.338905 seconds, 63296 images, 0.171287 hours left
# Loaded: 0.000044 seconds
#  total_bbox = 60411, rewritten_bbox = 0.000000 %
#  total_bbox = 60415, rewritten_bbox = 0.000000 %
#  total_bbox = 60418, rewritten_bbox = 0.000000 %
#  total_bbox = 60422, rewritten_bbox = 0.000000 %
#  total_bbox = 60426, rewritten_bbox = 0.000000 %
#  total_bbox = 60429, rewritten_bbox = 0.000000 %
#  total_bbox = 60433, rewritten_bbox = 0.000000 %
#  total_bbox = 60437, rewritten_bbox = 0.000000 %
#  total_bbox = 60441, rewritten_bbox = 0.000000 %
#  total_bbox = 60445, rewritten_bbox = 0.000000 %
#  total_bbox = 60449, rewritten_bbox = 0.000000 %
#  total_bbox = 60453, rewritten_bbox = 0.000000 %
#  total_bbox = 60457, rewritten_bbox = 0.000000 %
#  total_bbox = 60460, rewritten_bbox = 0.000000 %
#  total_bbox = 60464, rewritten_bbox = 0.000000 %
#  total_bbox = 60468, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 95.68 %, best = 95.84 %
#  990: 0.073545, 0.044779 avg loss, 0.000100 rate, 7.312892 seconds, 63360 images, 0.169799 hours left
# Resizing, random_coef = 1.40
#
#  608 x 608
#  try to allocate additional workspace_size = 106.46 MB
#  CUDA allocate done!
# Loaded: 0.396649 seconds - performance bottleneck on CPU or Disk HDD/SSD
#  total_bbox = 60472, rewritten_bbox = 0.000000 %
#  total_bbox = 60476, rewritten_bbox = 0.000000 %
#  total_bbox = 60480, rewritten_bbox = 0.000000 %
#  total_bbox = 60483, rewritten_bbox = 0.000000 %
#  total_bbox = 60487, rewritten_bbox = 0.000000 %
#  total_bbox = 60491, rewritten_bbox = 0.000000 %
#  total_bbox = 60495, rewritten_bbox = 0.000000 %
#  total_bbox = 60499, rewritten_bbox = 0.000000 %
#  total_bbox = 60503, rewritten_bbox = 0.000000 %
#  total_bbox = 60507, rewritten_bbox = 0.000000 %
#  total_bbox = 60511, rewritten_bbox = 0.000000 %
#  total_bbox = 60515, rewritten_bbox = 0.000000 %
#  total_bbox = 60519, rewritten_bbox = 0.000000 %
#  total_bbox = 60523, rewritten_bbox = 0.000000 %
#  total_bbox = 60527, rewritten_bbox = 0.000000 %
#  total_bbox = 60531, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 95.68 %, best = 95.84 %
#  991: 0.039885, 0.044290 avg loss, 0.000100 rate, 7.294048 seconds, 63424 images, 0.168304 hours left
# Loaded: 0.000043 seconds
#  total_bbox = 60535, rewritten_bbox = 0.000000 %
#  total_bbox = 60539, rewritten_bbox = 0.000000 %
#  total_bbox = 60543, rewritten_bbox = 0.000000 %
#  total_bbox = 60547, rewritten_bbox = 0.000000 %
#  total_bbox = 60551, rewritten_bbox = 0.000000 %
#  total_bbox = 60555, rewritten_bbox = 0.000000 %
#  total_bbox = 60559, rewritten_bbox = 0.000000 %
#  total_bbox = 60561, rewritten_bbox = 0.000000 %
#  total_bbox = 60565, rewritten_bbox = 0.000000 %
#  total_bbox = 60569, rewritten_bbox = 0.000000 %
#  total_bbox = 60573, rewritten_bbox = 0.000000 %
#  total_bbox = 60577, rewritten_bbox = 0.000000 %
#  total_bbox = 60578, rewritten_bbox = 0.000000 %
#  total_bbox = 60582, rewritten_bbox = 0.000000 %
#  total_bbox = 60586, rewritten_bbox = 0.000000 %
#  total_bbox = 60590, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 95.68 %, best = 95.84 %
#  992: 0.071486, 0.047009 avg loss, 0.000100 rate, 7.295578 seconds, 63488 images, 0.166813 hours left
# Loaded: 0.000058 seconds
#  total_bbox = 60593, rewritten_bbox = 0.000000 %
#  total_bbox = 60596, rewritten_bbox = 0.000000 %
#  total_bbox = 60600, rewritten_bbox = 0.000000 %
#  total_bbox = 60603, rewritten_bbox = 0.000000 %
#  total_bbox = 60607, rewritten_bbox = 0.000000 %
#  total_bbox = 60611, rewritten_bbox = 0.000000 %
#  total_bbox = 60615, rewritten_bbox = 0.000000 %
#  total_bbox = 60619, rewritten_bbox = 0.000000 %
#  total_bbox = 60622, rewritten_bbox = 0.000000 %
#  total_bbox = 60626, rewritten_bbox = 0.000000 %
#  total_bbox = 60629, rewritten_bbox = 0.000000 %
#  total_bbox = 60632, rewritten_bbox = 0.000000 %
#  total_bbox = 60636, rewritten_bbox = 0.000000 %
#  total_bbox = 60640, rewritten_bbox = 0.000000 %
#  total_bbox = 60643, rewritten_bbox = 0.000000 %
#  total_bbox = 60645, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 95.68 %, best = 95.84 %
#  993: 0.044409, 0.046749 avg loss, 0.000100 rate, 7.320848 seconds, 63552 images, 0.165307 hours left
# Loaded: 0.000057 seconds
#  total_bbox = 60649, rewritten_bbox = 0.000000 %
#  total_bbox = 60653, rewritten_bbox = 0.000000 %
#  total_bbox = 60657, rewritten_bbox = 0.000000 %
#  total_bbox = 60661, rewritten_bbox = 0.000000 %
#  total_bbox = 60664, rewritten_bbox = 0.000000 %
#  total_bbox = 60668, rewritten_bbox = 0.000000 %
#  total_bbox = 60672, rewritten_bbox = 0.000000 %
#  total_bbox = 60676, rewritten_bbox = 0.000000 %
#  total_bbox = 60680, rewritten_bbox = 0.000000 %
#  total_bbox = 60684, rewritten_bbox = 0.000000 %
#  total_bbox = 60688, rewritten_bbox = 0.000000 %
#  total_bbox = 60692, rewritten_bbox = 0.000000 %
#  total_bbox = 60696, rewritten_bbox = 0.000000 %
#  total_bbox = 60699, rewritten_bbox = 0.000000 %
#  total_bbox = 60702, rewritten_bbox = 0.000000 %
#  total_bbox = 60706, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 95.68 %, best = 95.84 %
#  994: 0.046178, 0.046692 avg loss, 0.000100 rate, 7.271646 seconds, 63616 images, 0.163796 hours left
# Loaded: 0.000064 seconds
#  total_bbox = 60710, rewritten_bbox = 0.000000 %
#  total_bbox = 60714, rewritten_bbox = 0.000000 %
#  total_bbox = 60718, rewritten_bbox = 0.000000 %
#  total_bbox = 60722, rewritten_bbox = 0.000000 %
#  total_bbox = 60726, rewritten_bbox = 0.000000 %
#  total_bbox = 60730, rewritten_bbox = 0.000000 %
#  total_bbox = 60734, rewritten_bbox = 0.000000 %
#  total_bbox = 60738, rewritten_bbox = 0.000000 %
#  total_bbox = 60742, rewritten_bbox = 0.000000 %
#  total_bbox = 60746, rewritten_bbox = 0.000000 %
#  total_bbox = 60750, rewritten_bbox = 0.000000 %
#  total_bbox = 60754, rewritten_bbox = 0.000000 %
#  total_bbox = 60758, rewritten_bbox = 0.000000 %
#  total_bbox = 60762, rewritten_bbox = 0.000000 %
#  total_bbox = 60766, rewritten_bbox = 0.000000 %
#  total_bbox = 60770, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 95.68 %, best = 95.84 %
#  995: 0.048518, 0.046875 avg loss, 0.000100 rate, 7.386050 seconds, 63680 images, 0.162280 hours left
# Loaded: 0.000044 seconds
#  total_bbox = 60774, rewritten_bbox = 0.000000 %
#  total_bbox = 60778, rewritten_bbox = 0.000000 %
#  total_bbox = 60782, rewritten_bbox = 0.000000 %
#  total_bbox = 60786, rewritten_bbox = 0.000000 %
#  total_bbox = 60790, rewritten_bbox = 0.000000 %
#  total_bbox = 60794, rewritten_bbox = 0.000000 %
#  total_bbox = 60798, rewritten_bbox = 0.000000 %
#  total_bbox = 60802, rewritten_bbox = 0.000000 %
#  total_bbox = 60806, rewritten_bbox = 0.000000 %
#  total_bbox = 60809, rewritten_bbox = 0.000000 %
#  total_bbox = 60813, rewritten_bbox = 0.000000 %
#  total_bbox = 60817, rewritten_bbox = 0.000000 %
#  total_bbox = 60820, rewritten_bbox = 0.000000 %
#  total_bbox = 60824, rewritten_bbox = 0.000000 %
#  total_bbox = 60828, rewritten_bbox = 0.000000 %
#  total_bbox = 60832, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 95.68 %, best = 95.84 %
#  996: 0.036177, 0.045805 avg loss, 0.000100 rate, 7.363598 seconds, 63744 images, 0.160759 hours left
# Loaded: 0.000056 seconds
#  total_bbox = 60836, rewritten_bbox = 0.000000 %
#  total_bbox = 60839, rewritten_bbox = 0.000000 %
#  total_bbox = 60843, rewritten_bbox = 0.000000 %
#  total_bbox = 60847, rewritten_bbox = 0.000000 %
#  total_bbox = 60851, rewritten_bbox = 0.000000 %
#  total_bbox = 60854, rewritten_bbox = 0.000000 %
#  total_bbox = 60858, rewritten_bbox = 0.000000 %
#  total_bbox = 60861, rewritten_bbox = 0.000000 %
#  total_bbox = 60863, rewritten_bbox = 0.000000 %
#  total_bbox = 60867, rewritten_bbox = 0.000000 %
#  total_bbox = 60871, rewritten_bbox = 0.000000 %
#  total_bbox = 60875, rewritten_bbox = 0.000000 %
#  total_bbox = 60879, rewritten_bbox = 0.000000 %
#  total_bbox = 60881, rewritten_bbox = 0.000000 %
#  total_bbox = 60884, rewritten_bbox = 0.000000 %
#  total_bbox = 60888, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 95.68 %, best = 95.84 %
#  997: 0.026931, 0.043918 avg loss, 0.000100 rate, 7.374384 seconds, 63808 images, 0.159234 hours left
# Loaded: 0.000043 seconds
#  total_bbox = 60892, rewritten_bbox = 0.000000 %
#  total_bbox = 60896, rewritten_bbox = 0.000000 %
#  total_bbox = 60900, rewritten_bbox = 0.000000 %
#  total_bbox = 60904, rewritten_bbox = 0.000000 %
#  total_bbox = 60908, rewritten_bbox = 0.000000 %
#  total_bbox = 60912, rewritten_bbox = 0.000000 %
#  total_bbox = 60915, rewritten_bbox = 0.000000 %
#  total_bbox = 60919, rewritten_bbox = 0.000000 %
#  total_bbox = 60923, rewritten_bbox = 0.000000 %
#  total_bbox = 60927, rewritten_bbox = 0.000000 %
#  total_bbox = 60931, rewritten_bbox = 0.000000 %
#  total_bbox = 60934, rewritten_bbox = 0.000000 %
#  total_bbox = 60938, rewritten_bbox = 0.000000 %
#  total_bbox = 60942, rewritten_bbox = 0.000000 %
#  total_bbox = 60946, rewritten_bbox = 0.000000 %
#  total_bbox = 60947, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 95.68 %, best = 95.84 %
#  998: 0.047987, 0.044325 avg loss, 0.000100 rate, 7.340464 seconds, 63872 images, 0.157703 hours left
# Loaded: 0.000042 seconds
#  total_bbox = 60951, rewritten_bbox = 0.000000 %
#  total_bbox = 60955, rewritten_bbox = 0.000000 %
#  total_bbox = 60959, rewritten_bbox = 0.000000 %
#  total_bbox = 60963, rewritten_bbox = 0.000000 %
#  total_bbox = 60967, rewritten_bbox = 0.000000 %
#  total_bbox = 60971, rewritten_bbox = 0.000000 %
#  total_bbox = 60975, rewritten_bbox = 0.000000 %
#  total_bbox = 60979, rewritten_bbox = 0.000000 %
#  total_bbox = 60983, rewritten_bbox = 0.000000 %
#  total_bbox = 60986, rewritten_bbox = 0.000000 %
#  total_bbox = 60990, rewritten_bbox = 0.000000 %
#  total_bbox = 60993, rewritten_bbox = 0.000000 %
#  total_bbox = 60997, rewritten_bbox = 0.000000 %
#  total_bbox = 61001, rewritten_bbox = 0.000000 %
#  total_bbox = 61005, rewritten_bbox = 0.000000 %
#  total_bbox = 61009, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 95.68 %, best = 95.84 %
#  999: 0.040527, 0.043945 avg loss, 0.000100 rate, 7.339248 seconds, 63936 images, 0.156167 hours left
# Loaded: 0.000042 seconds
#  total_bbox = 61013, rewritten_bbox = 0.000000 %
#  total_bbox = 61017, rewritten_bbox = 0.000000 %
#  total_bbox = 61021, rewritten_bbox = 0.000000 %
#  total_bbox = 61025, rewritten_bbox = 0.000000 %
#  total_bbox = 61029, rewritten_bbox = 0.000000 %
#  total_bbox = 61033, rewritten_bbox = 0.000000 %
#  total_bbox = 61036, rewritten_bbox = 0.000000 %
#  total_bbox = 61040, rewritten_bbox = 0.000000 %
#  total_bbox = 61044, rewritten_bbox = 0.000000 %
#  total_bbox = 61048, rewritten_bbox = 0.000000 %
#  total_bbox = 61052, rewritten_bbox = 0.000000 %
#  total_bbox = 61056, rewritten_bbox = 0.000000 %
#  total_bbox = 61060, rewritten_bbox = 0.000000 %
#  total_bbox = 61064, rewritten_bbox = 0.000000 %
#  total_bbox = 61068, rewritten_bbox = 0.000000 %
#  total_bbox = 61072, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 95.68 %, best = 95.84 %
#  1000: 0.033657, 0.042916 avg loss, 0.000100 rate, 7.269703 seconds, 64000 images, 0.154625 hours left
# Resizing to initial size: 416 x 416  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
#
#  calculation mAP (mean average precision)...
#
#  detections_count = 82, unique_truth_count = 69
# class_id = 0, name = License Plate, ap = 95.62%   	 (TP = 67, FP = 3)
#
#  for conf_thresh = 0.25, precision = 0.96, recall = 0.97, F1-score = 0.96
#  for conf_thresh = 0.25, TP = 67, FP = 3, FN = 2, average IoU = 79.63 %
#
#  IoU threshold = 50 %, used Area-Under-Curve for each unique Recall
#  mean average precision (mAP@0.50) = 0.956199, or 95.62 %
#
# Set -points flag:
#  `-points 101` for MS COCO
#  `-points 11` for PascalVOC 2007 (uncomment `difficult` in voc.data)
#  `-points 0` (AUC) for ImageNet, PascalVOC 2010-2012, your custom dataset
#
#  mean_average_precision (mAP@0.5) = 0.956199

# %% [markdown]
# ### Caveat

# %% [markdown]
# Ideally, as the training process progress, training loss should decrease. However, we observed that occasionally (not always) training loss shoots up to suddenly around ~100 iterations. This may lead to a code crash also.
#
# In such cases, we recommend to restart the training process again and keep watch on training loss. It should decrease as training progress.

# %% [markdown]
# ### Download Link

# %% [markdown]
# After 500 iterations of training, model achieved mAP @ 0.5 around 94%. The same model can be downloaded from [here](https://www.dropbox.com/s/vw9omi6tjntp6vr/yolov3-LP-train_best.weights?dl=0) which we will use in LP detection using YOLO-Net for ALPR system in next notebook.

# %% [markdown]
# ## 4. Inference

# %% [markdown]
# ### 4.1 Download test image

# %%
# !wget "https://raw.githubusercontent.com/openalpr/benchmarks/master/endtoend/br/JOG9221.jpg" -O test_img.jpg
# Out:
# --2020-06-08 17:19:41--  https://raw.githubusercontent.com/openalpr/benchmarks/master/endtoend/br/JOG9221.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1008302 (985K) [image/jpeg]
# Saving to: ‘test_img.jpg’
#
# test_img.jpg        100%[===================>] 984.67K  --.-KB/s    in 0.1s
#
# 2020-06-08 17:19:41 (7.91 MB/s) - ‘test_img.jpg’ saved [1008302/1008302]

# %% [markdown]
# ### 4.2 Utility functions

# %% [markdown]
# Here, we define few utility functions like,
# - `getOutputsNames`: Get the names of the output layers for given input neural network.
# - `postprocess`: uses `cv.dnn.NMSBoxes` internally to perform non maximum suppression to eliminate redundant overlapping boxes with lower confidences
# - `drawPred:` to draw the predicted bounding box

# %%
#@title
# Import necessary modules
import cv2 as cv

# Get the names of the output layers
def getOutputsNames(net):
  """ Get the names of the output layers.
  
  Generally in a sequential CNN network there will be 
  only one output layer at the end. In the YOLOv3 
  architecture, there are multiple output layers giving
  out predictions. This function gives the names of the 
  output layers. An output layer is not connected to 
  any next layer.
  
  Args
    net : YOLOv3 architecture based neural network.
  """
  # Get the names of all the layers in the network
  layersNames = net.getLayerNames()
  # Get the names of the output layers, i.e. the layers with unconnected outputs
  return [layersNames[i[0] - 1] for i in net.getUnconnectedOutLayers()]

# Remove the bounding boxes with low confidence using non-maxima suppression
def postprocess(frame, outs, confThreshold, nmsThreshold=0.4):
  frameHeight = frame.shape[0]
  frameWidth = frame.shape[1]

  classIds = []
  confidences = []
  boxes = []
  # Scan through all the bounding boxes output from the network and keep only the
  # ones with high confidence scores. Assign the box's class label as the class with the highest score.
  classIds = []
  confidences = []
  boxes = []
  predictions = []

  for out in outs:
      # print("out.shape : ", out.shape)
      for detection in out:
          scores = detection[5:]
          classId = np.argmax(scores)
          confidence = scores[classId]
          if confidence > confThreshold:
              center_x = int(detection[0] * frameWidth)
              center_y = int(detection[1] * frameHeight)
              width = int(detection[2] * frameWidth)
              height = int(detection[3] * frameHeight)
              left = int(center_x - width / 2)
              top = int(center_y - height / 2)
              classIds.append(classId)
              confidences.append(float(confidence))
              boxes.append([left, top, width, height])

  # Perform non maximum suppression to eliminate redundant overlapping boxes with
  # lower confidences.
  if nmsThreshold:
    indices = cv.dnn.NMSBoxes(boxes, confidences, confThreshold, nmsThreshold)
  else:
    indices = [[x] for x in range(len(boxes))]

  for i in indices:
    i = i[0]
    box = boxes[i]
    left = box[0]
    top = box[1]
    width = box[2]
    height = box[3]
    predictions.append([classIds[i], confidences[i], [left, top, left + width, top + height]])

  return predictions

# Draw the predicted bounding box
def drawPred(frame, pred):
  classId = pred[0]
  conf = pred[1]
  box = pred[2]
  left, top, right, bottom =  box[0], box[1], box[2], box[3]
  # draw bounding box
  cv.rectangle(frame, (left, top), (right, bottom), (0, 255, 0), 3)

# %% [markdown]
# ### 4.3 Load the trained model

# %%
# Import necessary modules
import cv2 as cv
import numpy as np
import os

# Initialize the parameters
confThreshold = 0.2  # Confidence threshold
nmsThreshold  = 0.4  # Non-maximum suppression threshold
inpWidth      = 416  # Width of network's input image
inpHeight     = 416  # Height of network's input image
yolo_lp_confi_path    = "yolov3-LP-test.cfg"
yolo_lp_weights_path  = "backup/yolov3-LP-train_best.weights"

# Download the pre-trained model if your training was not complete
if not os.path.exists(yolo_lp_weights_path):
    print("Downloading Pretrained model...")
    # !wget https://www.dropbox.com/s/vw9omi6tjntp6vr/yolov3-LP-train_best.weights?dl=0 -O "backup/yolov3-LP-train_best.weights" --quiet


# load the network
lp_net = cv.dnn.readNetFromDarknet(yolo_lp_confi_path, yolo_lp_weights_path)
lp_net.setPreferableBackend(cv.dnn.DNN_BACKEND_OPENCV)
lp_net.setPreferableTarget(cv.dnn.DNN_TARGET_CPU)

# %% [markdown]
# ### 4.4 Infer on the test image

# %%
# read test image
test_img = cv.imread('test_img.jpg')
# Create a 4D blob from a frame.
blob = cv.dnn.blobFromImage(test_img, 1/255, (inpWidth, inpHeight), [0,0,0], 1, crop=False)
# Sets the input to the network
lp_net.setInput(blob)
# Runs the forward pass to get output of the output layers
outs = lp_net.forward(getOutputsNames(lp_net))
# Remove the bounding boxes with low confidence
predictions = postprocess(test_img, outs, confThreshold, nmsThreshold)

# %% [markdown]
# ### 4.5 Display inference

# %%
# Import necessary modules
import matplotlib
import matplotlib.pyplot as plt
for pred in predictions:
  drawPred(test_img, pred)
# Display inference
fig=plt.figure(figsize=(10, 10))
plt.imshow(test_img[:,:,::-1])

# %% [markdown]
# Here, we have trained License plate detector using YOLO, it is observed that the performance improves if the detection is applied after the vehicle detection step. We will see more about this in the implementations of ALPR system.
